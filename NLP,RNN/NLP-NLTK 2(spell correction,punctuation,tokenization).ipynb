# %%
import nltk

# %%
#nltk.download()

# %%
import textblob

# %%
pip install pyspellchecker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
str1='thankks for waching the class'

# %%
str1
# Out:
# 'thankks for waching the class'

# %%
tb=TextBlob(str1)

# %%
tb
# Out:
# TextBlob("thankks for waching the class")

# %%
tb.correct()
# Out:
# TextBlob("thanks for watching the class")

# %%
str2='Pythonn is new ggeneration languae'

# %%
tb2=TextBlob(str2)

# %%
tb2
# Out:
# TextBlob("Pythonn is new ggeneration languae")

# %%
tb2.correct()
# Out:
# TextBlob("Pythonn is new generation language")

# %%
from spellchecker import SpellChecker

# %%
#eng=SpellChecker()

# %%
#spanish=SpellChecker(language='es')

# %%
#french=SpellChecker(language='fr')

# %%
spell=SpellChecker()

# %%
str3='Pythonn is most popuar languae in softwar world'

# %%
list1=str3.split()

# %%
list1
# Out:
# ['Pythonn', 'is', 'most', 'popuar', 'languae', 'in', 'softwar', 'world']

# %%
sc_misspelled=spell.unknown(list1)

# %%
sc_misspelled
# Out:
# {'languae', 'popuar', 'pythonn', 'softwar'}

# %%
correct_word=[]
for word in sc_misspelled:
    word=spell.correction(word)
    correct_word.append(word)

print(correct_word)
# Out:
# ['software', 'language', 'python', 'popular']

# %%
correct_word=[]
for word in sc_misspelled:
    print(spell.candidates(word))
    word=spell.correction(word)
    correct_word.append(word)
print('*************************************')
print(correct_word)
# Out:
# {'software'}
# {'language'}
# {'python', 'pythons'}
# {'poplar', 'popular'}
# *************************************
# ['software', 'language', 'python', 'popular']

# %% [markdown]
# ## Punctuation

# %%
import pandas as pd
import numpy as np

# %%
import nltk

# %%
import string

# %%
punc=string.punctuation

# %%
punc
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
dfmovie=pd.read_csv(r'C:\Users\User\Downloads\NLP\IMDB Dataset.csv')

# %%
dfmovie
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
dfmovie['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the 
# ...

# %%
len(dfmovie['review'][0])
# Out:
# 1761

# %%
[i for i in dfmovie['review'][0]]
# Out:
# ['O',
#  'n',
#  'e',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'o',
#  't',
#  'h',
#  'e',
#  'r',
#  ' ',
#  'r',
#  'e',
#  'v',
#  'i',
#  'e',
#  'w',
#  'e',
#  'r',
#  's',
#  ' ',
#  'h',
#  'a',
#  's',
#  ' ',
#  'm',
#  'e',
#  'n',
#  't',
#  'i',
#  'o',
#  'n',
#  'e',
#  'd',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  'a',
#  'f',
#  't',
#  'e',
#  'r',
#  ' ',
#  'w',
#  'a',
#  't',
#  'c',
#  'h',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'j',
#  'u',
#  's',
#  't',
#  ' ',
#  '1',
#  ' ',
#  'O',
#  'z',
#  ' ',
#  'e',
#  'p',
#  'i',
#  's',
#  'o',
#  'd',
#  'e',
#  ' ',
#  'y',
#  'o',
#  'u',
#  "'",
#  'l',
#  'l',
#  ' ',
#  'b',
#  'e',
#  ' ',
#  'h',
#  'o',
#  'o',
#  'k',
#  'e',
#  'd',
#  '.',
#  ' ',
#  'T',
#  'h',
#  'e',
#  'y',
#  ' ',
#  'a',
#  'r',
#  'e',
#  ' ',
#  'r',
#  'i',
#  'g',
#  'h',
#  't',
#  ',',
#  ' ',
#  'a',
#  's',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'e',
# ...

# %%
punc
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
[i.lower() for i in dfmovie['review'][0] if i not in punc]
# Out:
# ['o',
#  'n',
#  'e',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'o',
#  't',
#  'h',
#  'e',
#  'r',
#  ' ',
#  'r',
#  'e',
#  'v',
#  'i',
#  'e',
#  'w',
#  'e',
#  'r',
#  's',
#  ' ',
#  'h',
#  'a',
#  's',
#  ' ',
#  'm',
#  'e',
#  'n',
#  't',
#  'i',
#  'o',
#  'n',
#  'e',
#  'd',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  'a',
#  'f',
#  't',
#  'e',
#  'r',
#  ' ',
#  'w',
#  'a',
#  't',
#  'c',
#  'h',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'j',
#  'u',
#  's',
#  't',
#  ' ',
#  '1',
#  ' ',
#  'o',
#  'z',
#  ' ',
#  'e',
#  'p',
#  'i',
#  's',
#  'o',
#  'd',
#  'e',
#  ' ',
#  'y',
#  'o',
#  'u',
#  'l',
#  'l',
#  ' ',
#  'b',
#  'e',
#  ' ',
#  'h',
#  'o',
#  'o',
#  'k',
#  'e',
#  'd',
#  ' ',
#  't',
#  'h',
#  'e',
#  'y',
#  ' ',
#  'a',
#  'r',
#  'e',
#  ' ',
#  'r',
#  'i',
#  'g',
#  'h',
#  't',
#  ' ',
#  'a',
#  's',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'e',
#  'x',
#  'a',
#  'c',
# ...

# %%
''.join([i.lower() for i in dfmovie['review'][0] if i not in punc])
# Out:
# 'one of the other reviewers has mentioned that after watching just 1 oz episode youll be hooked they are right as this is exactly what happened with mebr br the first thing that struck me about oz was its brutality and unflinching scenes of violence which set in right from the word go trust me this is not a show for the faint hearted or timid this show pulls no punches with regards to drugs sex or violence its is hardcore in the classic use of the wordbr br it is called oz as that is the nickname given to the oswald maximum security state penitentary it focuses mainly on emerald city an experimental section of the prison where all the cells have glass fronts and face inwards so privacy is not high on the agenda em city is home to manyaryans muslims gangstas latinos christians italians irish and moreso scuffles death stares dodgy dealings and shady agreements are never far awaybr br i would say the main appeal of the show is due to the fact that it goes where other shows wouldnt dare 
# ...

# %%
len(''.join([i.lower() for i in dfmovie['review'][0] if i not in punc]))
# Out:
# 1683

# %%
dfmovie
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
dfmovie['review']
# Out:
# 0        One of the other reviewers has mentioned that ...
# 1        A wonderful little production. <br /><br />The...
# 2        I thought this was a wonderful way to spend ti...
# 3        Basically there's a family where a little boy ...
# 4        Petter Mattei's "Love in the Time of Money" is...
#                                ...
# 49995    I thought this movie did a down right good job...
# 49996    Bad plot, bad dialogue, bad acting, idiotic di...
# 49997    I am a Catholic taught in parochial elementary...
# 49998    I'm going to have to disagree with the previou...
# 49999    No one expects the Star Trek movies to be high...
# Name: review, Length: 50000, dtype: object

# %%
dfmovie['message']=dfmovie['review'].map(lambda x : ''.join([i.lower() for i in x if i not in punc]))

# %%
dfmovie
# Out:
#                                                   review sentiment  \
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
#                                                  message
# 0      one of the other reviewers has mentioned that ...
# ...

# %%
a=dfmovie['review'].map(lambda x : len(x))

# %%
a.sum()
# Out:
# 65471551

# %%
b=dfmovie['message'].map(lambda x : len(x))

# %%
b.sum()
# Out:
# 62842623

# %% [markdown]
# ## Tokenization

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
dfmovie['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the 
# ...

# %%
sent=sent_tokenize(dfmovie['review'][0])

# %%
sent
# Out:
# ["One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked.",
#  'They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO.',
#  'Trust me, this is not a show for the faint hearted or timid.',
#  'This show pulls no punches with regards to drugs, sex or violence.',
#  'Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary.',
#  'It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda.',
# ...

# %%
type(sent)
# Out:
# list

# %%
len(sent)
# Out:
# 10

# %%
word_tokenize(dfmovie['review'][0]) # it converts punctuations also as seperate words. so better to remove punctuations first
# Out:
# ['One',
#  'of',
#  'the',
#  'other',
#  'reviewers',
#  'has',
#  'mentioned',
#  'that',
#  'after',
#  'watching',
#  'just',
#  '1',
#  'Oz',
#  'episode',
#  'you',
#  "'ll",
#  'be',
#  'hooked',
#  '.',
#  'They',
#  'are',
#  'right',
#  ',',
#  'as',
#  'this',
#  'is',
#  'exactly',
#  'what',
#  'happened',
#  'with',
#  'me.',
#  '<',
#  'br',
#  '/',
#  '>',
#  '<',
#  'br',
#  '/',
#  '>',
#  'The',
#  'first',
#  'thing',
#  'that',
#  'struck',
#  'me',
#  'about',
#  'Oz',
#  'was',
#  'its',
#  'brutality',
#  'and',
#  'unflinching',
#  'scenes',
#  'of',
#  'violence',
#  ',',
#  'which',
#  'set',
#  'in',
#  'right',
#  'from',
#  'the',
#  'word',
#  'GO',
#  '.',
#  'Trust',
#  'me',
#  ',',
#  'this',
#  'is',
#  'not',
#  'a',
#  'show',
#  'for',
#  'the',
#  'faint',
#  'hearted',
#  'or',
#  'timid',
#  '.',
#  'This',
#  'show',
#  'pulls',
#  'no',
#  'punches',
#  'with',
#  'regards',
#  'to',
#  'drugs',
#  ',',
#  'sex',
#  'or',
#  'violence',
# ...

# %%
dfmovie['review'][0].split() # here punctuations will not be considered as seperate words.
# Out:
# ['One',
#  'of',
#  'the',
#  'other',
#  'reviewers',
#  'has',
#  'mentioned',
#  'that',
#  'after',
#  'watching',
#  'just',
#  '1',
#  'Oz',
#  'episode',
#  "you'll",
#  'be',
#  'hooked.',
#  'They',
#  'are',
#  'right,',
#  'as',
#  'this',
#  'is',
#  'exactly',
#  'what',
#  'happened',
#  'with',
#  'me.<br',
#  '/><br',
#  '/>The',
#  'first',
#  'thing',
#  'that',
#  'struck',
#  'me',
#  'about',
#  'Oz',
#  'was',
#  'its',
#  'brutality',
#  'and',
#  'unflinching',
#  'scenes',
#  'of',
#  'violence,',
#  'which',
#  'set',
#  'in',
#  'right',
#  'from',
#  'the',
#  'word',
#  'GO.',
#  'Trust',
#  'me,',
#  'this',
#  'is',
#  'not',
#  'a',
#  'show',
#  'for',
#  'the',
#  'faint',
#  'hearted',
#  'or',
#  'timid.',
#  'This',
#  'show',
#  'pulls',
#  'no',
#  'punches',
#  'with',
#  'regards',
#  'to',
#  'drugs,',
#  'sex',
#  'or',
#  'violence.',
#  'Its',
#  'is',
#  'hardcore,',
#  'in',
#  'the',
#  'classic',
#  'use',
#  'of',
#  'the',
# ...
