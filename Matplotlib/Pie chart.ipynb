# %%
import pandas as pd 
import numpy as  np

# %%
import matplotlib.pyplot as plt

# %%
plt.pie([0.5,0.3,0.2])
# Out:
# ([<matplotlib.patches.Wedge at 0x1d88271dd30>,
# ...
#  [Text(6.735557395310444e-17, 1.1, ''),
#   Text(-0.6465637441936395, -0.8899187180267095, ''),
#   Text(0.8899187482945414, -0.6465637025335375, '')])

# %%
course = ["Py", "R", "ML", "AI"]
std = [30, 20,50,40]

# %%
plt.pie(std, labels=course)
plt.show()

# %%
course
# Out:
# ['Py', 'R', 'ML', 'AI']

# %%
std
# Out:
# [30, 20, 50, 40]

# %%
ep = [0,0,0.1,0]

# %%
c = ["b", "y", "r", "c"]

# %%
plt.pie(std, labels=course, explode = ep, colors = c, autopct = "%0.2f%%", 
        radius= 1.8,
        shadow=True)
plt.show()

# %%
plt.subplot(2,2,1)
plt.pie([1])
plt.subplot(2,2,2)
plt.pie([1,2])
plt.subplot(2,2,3)
plt.pie([1,2,3])
plt.subplot(2,2,4)
plt.pie([1,2,3])
# Out:
# ([<matplotlib.patches.Wedge at 0x1d88274fc40>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, ''),
#   Text(-0.5500000594609755, 0.9526279098330699, ''),
#   Text(1.0298943251329445e-07, -1.0999999999999954, '')])
