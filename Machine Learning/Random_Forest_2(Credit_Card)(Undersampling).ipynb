# %%
import numpy as np
import pandas as pd

# %%
dfcc=pd.read_csv(r'C:\Users\User\Downloads\ML Dataset\creditcard.csv')

# %%
dfcc
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
# 0--> valid transaction and 1-->Invalid transaction

# %%
dfcc.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
dfcc.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
dfcc['Class']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
dfcc['Class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
dfcc['Class'].value_counts() # these values shows that sampling is not done properly bcoz we have collected huge data on valid transaction(0) but not much data on invalid transaction(1),
# hence it will not give accurate results,bcoz when we split the data there are less chances that we get 1 values in training data.So,model will learn only 0 but not 1 hence model will be failed to predict invalid transactions.
# Balanced Data==>50-50%,60-40% and sometimes 65-35% is also ok,but in this case invalid transaction dta is not even 1% of the total data.
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
dfcc['Class'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dfcc.shape
# Out:
# (284807, 31)

# %% [markdown]
# ### Seperating 0 and 1

# %%
dfvalid=dfcc[dfcc['Class']==0]

# %%
dfvalid
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
dfinvalid=dfcc[dfcc['Class']==1]

# %%
dfinvalid
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
dfvalid.shape
# Out:
# (284315, 31)

# %%
dfinvalid.shape
# Out:
# (492, 31)

# %%
# We will keep dfinvalid as it is but we will make dfvalid.shape equal to dfinvalid.shape

# %%
dfvalid.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 192255  129609.0  2.001806  0.089919 -1.867047  0.332245  0.419871 -0.882986
# 225139  144122.0  1.824400 -0.804925 -2.297259 -0.598779  2.009693  3.603521
# 273999  165805.0  1.881007 -0.004118 -1.784197  1.214787  0.688476 -0.394307
# 282198  170725.0  0.094618  0.903707 -0.005935 -0.768838  0.845070 -0.672071
# 6759      8496.0  1.214854 -0.212503  0.652639  0.501414  0.048638  1.517130
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 192255  0.168115 -0.200283  0.360229  ...  0.236524  0.792770 -0.089570
# 225139 -0.690265  0.878962  0.903734  ...  0.086364  0.122802  0.126507
# 273999  0.572125 -0.201408 -0.101188  ...  0.134739  0.415423 -0.028653
# 282198  1.061046 -0.209057 -0.124319  ... -0.298949 -0.639246 -0.029312
# 6759   -0.941984  0.396034  2.095510  ... -0.276772 -0.361549 -0.154047
#
# ...

# %%
df1=dfvalid.sample(492)

# %%
df1
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 173144  121366.0  2.069317  0.145643 -1.999323  1.045025  0.924132 -0.334107
# 108283   70836.0 -0.950654  1.156170  1.706320  0.617770 -0.202484  0.465604
# 174803  122075.0 -2.689224  0.054246 -1.198699 -0.526363 -0.319321 -1.290346
# 262196  160358.0 -0.551232  0.113910 -0.828650 -3.205206  0.200086 -0.333178
# 175919  122552.0  0.038772  0.020082 -0.547672  0.430222  0.804840 -0.754020
# ...          ...       ...       ...       ...       ...       ...       ...
# 89398    62561.0 -0.890333  0.794299  2.013015  1.615412 -0.836230  1.019844
# 153419   99011.0  1.896371 -0.469472 -0.261319  0.530420 -0.480868  0.240558
# 29036    35288.0  1.051761 -0.374105  0.865939  1.506367 -0.542051  0.919989
# 35394    38103.0  0.926968 -1.007067  0.563517 -1.393641 -0.974723  0.145188
# 212107  138717.0 -0.743968  0.071388  1.943182 -1.618826  0.193963  0.549749
#
# ...

# %%
df1['Class'].unique()
# Out:
# array([0], dtype=int64)

# %%
dfinvalid["Class"].unique()
# Out:
# array([1], dtype=int64)

# %%
df1.shape
# Out:
# (492, 31)

# %%
dfinvalid.shape
# Out:
# (492, 31)

# %%
dfcard=pd.concat([dfinvalid,df1])

# %%
dfcard
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 89398    62561.0 -0.890333  0.794299  2.013015  1.615412 -0.836230  1.019844
# 153419   99011.0  1.896371 -0.469472 -0.261319  0.530420 -0.480868  0.240558
# 29036    35288.0  1.051761 -0.374105  0.865939  1.506367 -0.542051  0.919989
# 35394    38103.0  0.926968 -1.007067  0.563517 -1.393641 -0.974723  0.145188
# 212107  138717.0 -0.743968  0.071388  1.943182 -1.618826  0.193963  0.549749
#
# ...

# %%
dfcard["Class"].value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
dfcard["Class"].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Class'>

# %%
dfcard["Class"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Seperate and split

# %%
dfcard
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 89398    62561.0 -0.890333  0.794299  2.013015  1.615412 -0.836230  1.019844
# 153419   99011.0  1.896371 -0.469472 -0.261319  0.530420 -0.480868  0.240558
# 29036    35288.0  1.051761 -0.374105  0.865939  1.506367 -0.542051  0.919989
# 35394    38103.0  0.926968 -1.007067  0.563517 -1.393641 -0.974723  0.145188
# 212107  138717.0 -0.743968  0.071388  1.943182 -1.618826  0.193963  0.549749
#
# ...

# %%
dfcard=dfcard.reset_index()

# %%
dfcard
# Out:
#       index      Time        V1        V2        V3        V4        V5  \
# 0       541     406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188
# 1       623     472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805
# 2      4920    4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628
# 3      6108    6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131
# 4      6329    7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201
# ..      ...       ...       ...       ...       ...       ...       ...
# 979   89398   62561.0 -0.890333  0.794299  2.013015  1.615412 -0.836230
# 980  153419   99011.0  1.896371 -0.469472 -0.261319  0.530420 -0.480868
# 981   29036   35288.0  1.051761 -0.374105  0.865939  1.506367 -0.542051
# 982   35394   38103.0  0.926968 -1.007067  0.563517 -1.393641 -0.974723
# 983  212107  138717.0 -0.743968  0.071388  1.943182 -1.618826  0.193963
#
#            V6        V7        V8  ...       V21       V22       V23  \
# ...

# %%
dfcard.drop('index',axis=1,inplace=True)

# %%
dfcard
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0       406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 1       472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 2      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 3      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 4      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ..        ...       ...       ...       ...       ...       ...       ...
# 979   62561.0 -0.890333  0.794299  2.013015  1.615412 -0.836230  1.019844
# 980   99011.0  1.896371 -0.469472 -0.261319  0.530420 -0.480868  0.240558
# 981   35288.0  1.051761 -0.374105  0.865939  1.506367 -0.542051  0.919989
# 982   38103.0  0.926968 -1.007067  0.563517 -1.393641 -0.974723  0.145188
# 983  138717.0 -0.743968  0.071388  1.943182 -1.618826  0.193963  0.549749
#
#            V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
X=dfcard.drop('Class',axis=1)

# %%
X
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0       406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 1       472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 2      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 3      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 4      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ..        ...       ...       ...       ...       ...       ...       ...
# 979   62561.0 -0.890333  0.794299  2.013015  1.615412 -0.836230  1.019844
# 980   99011.0  1.896371 -0.469472 -0.261319  0.530420 -0.480868  0.240558
# 981   35288.0  1.051761 -0.374105  0.865939  1.506367 -0.542051  0.919989
# 982   38103.0  0.926968 -1.007067  0.563517 -1.393641 -0.974723  0.145188
# 983  138717.0 -0.743968  0.071388  1.943182 -1.618826  0.193963  0.549749
#
#            V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
y=dfcard['Class']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 979    0
# 980    0
# 981    0
# 982    0
# 983    0
# Name: Class, Length: 984, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.20)

# %%
Xtrain.shape,Xtest.shape,X.shape
# Out:
# ((787, 30), (197, 30), (984, 30))

# %%
ytrain.shape,ytest.shape,y.shape
# Out:
# ((787,), (197,), (984,))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(Xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
rfc.score(Xtest,ytest)
# Out:
# 0.9390862944162437
