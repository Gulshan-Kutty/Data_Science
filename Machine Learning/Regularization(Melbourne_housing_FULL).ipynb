# %%
import pandas as pd
import numpy as np

# %%
dfhprice=pd.read_csv(r'C:\Users\User\Downloads\ML Dataset\Linear Regression\Regularization\Melbourne_housing_FULL.csv')

# %%
dfhprice
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
dfhprice.isna()
# Out:
#        Suburb  Rooms   Type  Price  Method  SellerG  Distance  Bedroom2  \
# 0       False  False  False   True   False    False     False     False
# 1       False  False  False  False   False    False     False     False
# 2       False  False  False  False   False    False     False     False
# 3       False  False  False   True   False    False     False     False
# 4       False  False  False  False   False    False     False     False
# ...       ...    ...    ...    ...     ...      ...       ...       ...
# 34852   False  False  False  False   False    False     False     False
# 34853   False  False  False  False   False    False     False     False
# 34854   False  False  False  False   False    False     False     False
# 34855   False  False  False  False   False    False     False      True
# 34856   False  False  False  False   False    False     False     False
#
#        Bathroom    Car  Landsize  BuildingArea  CouncilArea  Regionname  \
# ...

# %%
dfhprice.isna().sum() # isna()=isnull()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
dfhprice.isna().sum().sum()
# Out:
# 65716

# %%
# Our core purpose is to land this data in overfitting so don't bother about the preprocessing(cleaning) of the data.

# %%
dfhprice.columns
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Distance',
#        'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea',
#        'CouncilArea', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
cols=['Distance','Bedroom2','Bathroom','Car','Propertycount'] # we are making all the nan values of all these columns as zero.

# %%
cols
# Out:
# ['Distance', 'Bedroom2', 'Bathroom', 'Car', 'Propertycount']

# %%
dfhprice[cols]
# OR dfhprice[['Distance','Bedroom2','Bathroom','Car','Propertycount']]
# Out:
#        Distance  Bedroom2  Bathroom  Car  Propertycount
# 0           2.5       2.0       1.0  1.0         4019.0
# 1           2.5       2.0       1.0  1.0         4019.0
# 2           2.5       2.0       1.0  0.0         4019.0
# 3           2.5       3.0       2.0  1.0         4019.0
# 4           2.5       3.0       2.0  0.0         4019.0
# ...         ...       ...       ...  ...            ...
# 34852       6.3       4.0       1.0  3.0         6543.0
# 34853       6.3       2.0       2.0  1.0         6543.0
# 34854       6.3       2.0       1.0  2.0         6543.0
# 34855       6.3       NaN       NaN  NaN         6543.0
# 34856       6.3       2.0       1.0  0.0         6543.0
#
# [34857 rows x 5 columns]

# %%
dfhprice[cols].isna().sum()
# Out:
# Distance            1
# Bedroom2         8217
# Bathroom         8226
# Car              8728
# Propertycount       3
# dtype: int64

# %%
dfhprice[cols]=dfhprice[cols].fillna(0)

# %%
dfhprice.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        0
# dtype: int64

# %%
dfhprice['Landsize'].isna().sum()
# Out:
# 11810

# %%
m1=dfhprice['Landsize'].mean()

# %%
m1
# Out:
# 593.598993361392

# %%
# dfhprice['Landsize'].fillna(m1)
dfhprice['Landsize'].fillna(dfhprice['Landsize'].mean())
# Out:
# 0        126.000000
# 1        202.000000
# 2        156.000000
# 3          0.000000
# 4        134.000000
#             ...
# 34852    593.000000
# 34853     98.000000
# 34854    220.000000
# 34855    593.598993
# 34856    250.000000
# Name: Landsize, Length: 34857, dtype: float64

# %%
dfhprice['Landsize'].fillna(dfhprice['Landsize'].mean()).isna().sum()
# Out:
# 0

# %%
dfhprice['Landsize']=dfhprice['Landsize'].fillna(dfhprice['Landsize'].mean()) # Permanent change

# %%
dfhprice.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize             0
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        0
# dtype: int64

# %%
dfhprice['BuildingArea'].isna().sum()
# Out:
# 21115

# %%
dfhprice['BuildingArea'].mean()
# Out:
# 160.2564003565711

# %%
dfhprice['BuildingArea'].fillna(dfhprice['BuildingArea'].mean())
# Out:
# 0        160.2564
# 1        160.2564
# 2         79.0000
# 3        160.2564
# 4        150.0000
#            ...
# 34852    160.2564
# 34853    104.0000
# 34854    120.0000
# 34855    160.2564
# 34856    103.0000
# Name: BuildingArea, Length: 34857, dtype: float64

# %%
dfhprice['BuildingArea'].fillna(dfhprice['BuildingArea'].mean()).isna().sum()
# Out:
# 0

# %%
dfhprice['BuildingArea']=dfhprice['BuildingArea'].fillna(dfhprice['BuildingArea'].mean())

# %%
dfhprice.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Price            7610
# Method              0
# SellerG             0
# Distance            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# CouncilArea         3
# Regionname          3
# Propertycount       0
# dtype: int64

# %%
dfhprice.dropna(inplace=True)

# %%
dfhprice.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Distance         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# CouncilArea      0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
dfhprice.shape
# Out:
# (27244, 15)

# %% [markdown]
# # Encoding

# %%
dfhprice.dtypes # there are 6 categorical columns
# Out:
# Suburb            object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Distance         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# CouncilArea       object
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
dfhprice[['Suburb', 'Type', 'Method', 'SellerG',
       'CouncilArea', 'Regionname']]
# Out:
#            Suburb Type Method        SellerG               CouncilArea  \
# 1      Abbotsford    h      S         Biggin        Yarra City Council
# 2      Abbotsford    h      S         Biggin        Yarra City Council
# 4      Abbotsford    h     SP         Biggin        Yarra City Council
# 5      Abbotsford    h     PI         Biggin        Yarra City Council
# 6      Abbotsford    h     VB         Nelson        Yarra City Council
# ...           ...  ...    ...            ...                       ...
# 34852  Yarraville    h     PI            Jas  Maribyrnong City Council
# 34853  Yarraville    h     SP        Sweeney  Maribyrnong City Council
# 34854  Yarraville    t      S            Jas  Maribyrnong City Council
# 34855  Yarraville    h     SP  hockingstuart  Maribyrnong City Council
# 34856  Yarraville    h     PI             RW  Maribyrnong City Council
#
#                   Regionname
# 1      Northern Metropolitan
# 2      Northern Metropolitan
# ...

# %%
pd.get_dummies(dfhprice[['Suburb', 'Type', 'Method', 'SellerG',
       'CouncilArea', 'Regionname']])
# Out:
#        Suburb_Abbotsford  Suburb_Aberfeldie  Suburb_Airport West  \
# 1                      1                  0                    0
# 2                      1                  0                    0
# 4                      1                  0                    0
# 5                      1                  0                    0
# 6                      1                  0                    0
# ...                  ...                ...                  ...
# 34852                  0                  0                    0
# 34853                  0                  0                    0
# 34854                  0                  0                    0
# 34855                  0                  0                    0
# 34856                  0                  0                    0
#
#        Suburb_Albanvale  Suburb_Albert Park  Suburb_Albion  Suburb_Alphington  \
# 1                     0                   0              0                  0
# ...

# %%
dfhprice
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# 5      Abbotsford      3    h   850000.0     PI         Biggin       2.5
# 6      Abbotsford      4    h  1600000.0     VB         Nelson       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %%
dfhprice=pd.get_dummies(dfhprice,drop_first=True)

# %%
dfhprice
# Out:
#        Rooms      Price  Distance  Bedroom2  Bathroom  Car    Landsize  \
# 1          2  1480000.0       2.5       2.0       1.0  1.0  202.000000
# 2          2  1035000.0       2.5       2.0       1.0  0.0  156.000000
# 4          3  1465000.0       2.5       3.0       2.0  0.0  134.000000
# 5          3   850000.0       2.5       3.0       2.0  1.0   94.000000
# 6          4  1600000.0       2.5       3.0       1.0  2.0  120.000000
# ...      ...        ...       ...       ...       ...  ...         ...
# 34852      4  1480000.0       6.3       4.0       1.0  3.0  593.000000
# 34853      2   888000.0       6.3       2.0       2.0  1.0   98.000000
# 34854      2   705000.0       6.3       2.0       1.0  2.0  220.000000
# 34855      3  1140000.0       6.3       0.0       0.0  0.0  593.598993
# 34856      2  1020000.0       6.3       2.0       1.0  0.0  250.000000
#
#        BuildingArea  Propertycount  Suburb_Aberfeldie  ...  \
# ...

# %%
dfhprice.dtypes
# Out:
# Rooms                                      int64
# Price                                    float64
# Distance                                 float64
# Bedroom2                                 float64
# Bathroom                                 float64
#                                           ...
# Regionname_Northern Victoria               uint8
# Regionname_South-Eastern Metropolitan      uint8
# Regionname_Southern Metropolitan           uint8
# Regionname_Western Metropolitan            uint8
# Regionname_Western Victoria                uint8
# Length: 745, dtype: object

# %% [markdown]
# # Splitting

# %%
X=dfhprice.drop('Price',axis=1)

# %%
X
# Out:
#        Rooms  Distance  Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# 1          2       2.5       2.0       1.0  1.0  202.000000      160.2564
# 2          2       2.5       2.0       1.0  0.0  156.000000       79.0000
# 4          3       2.5       3.0       2.0  0.0  134.000000      150.0000
# 5          3       2.5       3.0       2.0  1.0   94.000000      160.2564
# 6          4       2.5       3.0       1.0  2.0  120.000000      142.0000
# ...      ...       ...       ...       ...  ...         ...           ...
# 34852      4       6.3       4.0       1.0  3.0  593.000000      160.2564
# 34853      2       6.3       2.0       2.0  1.0   98.000000      104.0000
# 34854      2       6.3       2.0       1.0  2.0  220.000000      120.0000
# 34855      3       6.3       0.0       0.0  0.0  593.598993      160.2564
# 34856      2       6.3       2.0       1.0  0.0  250.000000      103.0000
#
#        Propertycount  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# ...

# %%
y=dfhprice['Price']

# %%
y
# Out:
# 1        1480000.0
# 2        1035000.0
# 4        1465000.0
# 5         850000.0
# 6        1600000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 27244, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.30,random_state=2)

# %%
Xtrain.shape,Xtest.shape,X.shape
# Out:
# ((19070, 744), (8174, 744), (27244, 744))

# %% [markdown]
# ## Linear Regression Algorithm

# %%
from sklearn.linear_model import LinearRegression

# %%
lrmodel=LinearRegression()

# %%
lrmodel
# Out:
# LinearRegression()

# %%
lrmodel.fit(Xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lrmodel.score(Xtest,ytest)
# Out:
# 0.13853683161538477

# %%
lrmodel.score(Xtrain,ytrain) # this is the case of Overfitting
# Out:
# 0.6827792395792723

# %% [markdown]
# ## Regularization with Ridge and Lasso

# %%
from sklearn.linear_model import Ridge

# %%
rg=Ridge()

# %%
rg
# Out:
# Ridge()

# %%
rg.fit(Xtrain,ytrain)
# Out:
# Ridge()

# %%
rg.score(Xtest,ytest)
# Out:
# 0.6701765758295282

# %%
rg.score(Xtrain,ytrain)
# Out:
# 0.6796668251040214
