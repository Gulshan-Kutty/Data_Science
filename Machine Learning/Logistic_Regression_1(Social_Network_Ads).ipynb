# %%
import numpy as np
import pandas as pd

# %%
dfsocial=pd.read_csv(r'C:\Users\User\Downloads\ML Dataset\Decision Tree\Social_Network_Ads.csv')

# %%
dfsocial
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dfsocial.isna().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
dfsocial.dtypes
# Out:
# User ID             int64
# Gender             object
# Age                 int64
# EstimatedSalary     int64
# Purchased           int64
# dtype: object

# %%
pd.get_dummies(dfsocial) # as there is only one categorical column, we can directly apply get_dummies on entire dataset.
# automatically Gender column will be replaced by Gender_Female and Gender_Male.
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Female  Gender_Male
# 0    15624510   19            19000          0              0            1
# 1    15810944   35            20000          0              0            1
# 2    15668575   26            43000          0              1            0
# 3    15603246   27            57000          0              1            0
# 4    15804002   19            76000          0              0            1
# ..        ...  ...              ...        ...            ...          ...
# 395  15691863   46            41000          1              1            0
# 396  15706071   51            23000          1              0            1
# 397  15654296   50            20000          1              1            0
# 398  15755018   36            33000          0              0            1
# 399  15594041   49            36000          1              1            0
#
# [400 rows x 6 columns]

# %%
dfsocial=pd.get_dummies(dfsocial,drop_first=True)

# %%
dfsocial
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dfsocial.drop('User ID',axis=1,inplace=True)

# %%
dfsocial
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dfsocial.columns=['Age','EstimatedSalary','Male','Purchased']

# %%
dfsocial
# Out:
#      Age  EstimatedSalary  Male  Purchased
# 0     19            19000     0          1
# 1     35            20000     0          1
# 2     26            43000     0          0
# 3     27            57000     0          0
# 4     19            76000     0          1
# ..   ...              ...   ...        ...
# 395   46            41000     1          0
# 396   51            23000     1          1
# 397   50            20000     1          0
# 398   36            33000     0          1
# 399   49            36000     1          0
#
# [400 rows x 4 columns]

# %%
X=dfsocial.drop('Purchased',axis=1)

# %%
X
# Out:
#      Age  EstimatedSalary  Male
# 0     19            19000     0
# 1     35            20000     0
# 2     26            43000     0
# 3     27            57000     0
# 4     19            76000     0
# ..   ...              ...   ...
# 395   46            41000     1
# 396   51            23000     1
# 397   50            20000     1
# 398   36            33000     0
# 399   49            36000     1
#
# [400 rows x 3 columns]

# %%
y=dfsocial['Purchased']

# %%
y
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 395    0
# 396    1
# 397    0
# 398    1
# 399    0
# Name: Purchased, Length: 400, dtype: uint8

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.20)

# %%
Xtrain.shape,Xtest.shape,X.shape
# Out:
# ((320, 3), (80, 3), (400, 3))

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgmodel=LogisticRegression()

# %%
lgmodel
# Out:
# LogisticRegression()

# %%
lgmodel.fit(Xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
lgmodel.score(Xtest,ytest)
# Out:
# 0.4625

# %% [markdown]
# # Scaling Method

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
ss.fit(Xtrain)
# Out:
# StandardScaler()

# %%
Xtrain_ss=ss.transform(Xtrain)

# %%
Xtest_ss=ss.transform(Xtest)

# %%
Xtrain
# Out:
#      Age  EstimatedSalary  Male
# 393   60            42000     1
# 373   59           130000     1
# 162   37            33000     0
# 111   37            71000     0
# 73    33           113000     0
# ..   ...              ...   ...
# 26    49            28000     1
# 231   39            42000     0
# 129   26            84000     0
# 266   40            75000     0
# 191   19            26000     0
#
# [320 rows x 3 columns]

# %%
Xtrain_ss
# Out:
# array([[ 2.13352685, -0.7936789 ,  1.32612997],
#        [ 2.03800025,  1.77853861,  1.32612997],
#        [-0.06358489, -1.0567466 , -0.7540739 ],
#        [-0.06358489,  0.05398368, -0.7540739 ],
#        [-0.44569128,  1.28163295, -0.7540739 ],
#        [ 0.70062789,  1.80776835,  1.32612997],
#        [ 0.3185215 , -1.14443584, -0.7540739 ],
#        [ 0.89168108, -1.14443584,  1.32612997],
#        [ 0.98720768,  1.89545758,  1.32612997],
#        [ 0.2229949 , -0.2675435 , -0.7540739 ],
#        [ 0.79615448,  0.37551087, -0.7540739 ],
#        [-1.40095725, -1.43673328, -0.7540739 ],
#        [-1.30543066,  0.43397036, -0.7540739 ],
#        [-1.68753705,  0.14167292, -0.7540739 ],
#        [-0.06358489,  0.22936215, -0.7540739 ],
#        [-0.92332427, -0.93982763, -0.7540739 ],
#        [-0.63674448, -1.582882  , -0.7540739 ],
#        [ 2.03800025, -1.17366558,  1.32612997],
#        [-0.35016468,  1.34009244, -0.7540739 ],
#        [-0.25463809, -0.91059788, -0.7540739 ],
# ...

# %%
Xtest
# Out:
#      Age  EstimatedSalary  Male
# 321   53            82000     1
# 234   38           112000     0
# 105   21            72000     0
# 258   58            95000     1
# 117   36            52000     0
# ..   ...              ...   ...
# 375   46            32000     1
# 69    31            68000     0
# 309   38            50000     0
# 38    26            72000     0
# 394   39            59000     0
#
# [80 rows x 3 columns]

# %%
Xtest_ss
# Out:
# array([[ 1.46484067,  0.37551087,  1.32612997],
#        [ 0.03194171,  1.25240321, -0.7540739 ],
#        [-1.59201045,  0.08321343, -0.7540739 ],
#        [ 1.94247365,  0.75549755,  1.32612997],
#        [-0.15911149, -0.50138146, -0.7540739 ],
#        [-1.49648385, -1.23212507, -0.7540739 ],
#        [ 0.1274683 ,  1.54470065,  1.32612997],
#        [-1.78306364,  0.46320011, -0.7540739 ],
#        [ 1.27378747,  1.89545758, -0.7540739 ],
#        [ 0.98720768, -1.14443584,  1.32612997],
#        [-0.92332427,  0.58011908, -0.7540739 ],
#        [-0.35016468,  1.25240321,  1.32612997],
#        [ 0.4140481 , -0.15062453, -0.7540739 ],
#        [-0.25463809,  0.08321343, -0.7540739 ],
#        [ 1.56036726,  0.02475394,  1.32612997],
#        [-1.11437746,  0.31705138, -0.7540739 ],
#        [ 1.56036726,  1.13548423,  1.32612997],
#        [ 0.03194171,  0.05398368, -0.7540739 ],
#        [-0.63674448, -1.49519277, -0.7540739 ],
#        [ 1.75142046,  1.86622784,  1.32612997],
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgreg=LogisticRegression()

# %%
lgreg
# Out:
# LogisticRegression()

# %%
lgreg.fit(Xtrain_ss,ytrain)
# Out:
# LogisticRegression()

# %%
lgreg.score(Xtest_ss,ytest)
# Out:
# 0.4875
