# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv(r'C:\Users\User\Downloads\DATASETS\Crosstab\crosstab_dataset.csv')

# %%
df1
# Out:
#         Name  Gender Country         Degree  Age
# 0     Shanti  Female   India  Post Graduate   23
# 1      Naren    Male   India       Graduate   20
# 2      Kumar    Male   India       Graduate   27
# 3    Narayan    Male   India  Post Graduate   25
# 4      Shiva    Male   India       Graduate   28
# 5      Meena  Female   India  Post Graduate   25
# 6      Akash    Male   India       Graduate   24
# 7    Sandhya  Female   India       Graduate   26
# 8    Kumaran    Male   India       Graduate   27
# 9      Naren    Male   India  Post Graduate   25
# 10    Swarna  Female   India  Post Graduate   28
# 11  Srikruti  Female   India  Post Graduate   25
# 12   Rus_f01  Female  Russia       Graduate   30
# 13   Rus_m01    Male  Russia       Graduate   32
# 14   Rus_f02  Female  Russia  Post Graduate   28
# 15   Rus_f03  Female  Russia       Graduate   34
# 16   Rus_m02    Male  Russia       Graduate   30
# 17   Rus_f04  Female  Russia  Post Graduate   36
# ...

# %%
df1.columns
# Out:
# Index(['Name', 'Gender', 'Country', 'Degree', 'Age'], dtype='object')

# %%
df1['Country'].unique()
# Out:
# array(['India', 'Russia', 'Usa'], dtype=object)

# %%
df1["Country"].value_counts()
# Out:
# India     12
# Usa       10
# Russia     7
# Name: Country, dtype: int64

# %%
df1.groupby(['Country','Gender']).count()
# Out:
#                 Name  Degree  Age
# Country Gender
# India   Female     5       5    5
#         Male       7       7    7
# Russia  Female     4       4    4
#         Male       3       3    3
# Usa     Female     6       6    6
#         Male       4       4    4

# %%
df1.groupby(['Country','Degree','Gender']).count()
# Out:
#                               Name  Age
# Country Degree        Gender
# India   Graduate      Female     1    1
#                       Male       5    5
#         Post Graduate Female     4    4
#                       Male       2    2
# Russia  Graduate      Female     2    2
#                       Male       3    3
#         Post Graduate Female     2    2
# Usa     Graduate      Female     4    4
#                       Male       1    1
#         Post Graduate Female     2    2
#                       Male       3    3

# %%
# now with crosstab

# %%
df1
# Out:
#         Name  Gender Country         Degree  Age
# 0     Shanti  Female   India  Post Graduate   23
# 1      Naren    Male   India       Graduate   20
# 2      Kumar    Male   India       Graduate   27
# 3    Narayan    Male   India  Post Graduate   25
# 4      Shiva    Male   India       Graduate   28
# 5      Meena  Female   India  Post Graduate   25
# 6      Akash    Male   India       Graduate   24
# 7    Sandhya  Female   India       Graduate   26
# 8    Kumaran    Male   India       Graduate   27
# 9      Naren    Male   India  Post Graduate   25
# 10    Swarna  Female   India  Post Graduate   28
# 11  Srikruti  Female   India  Post Graduate   25
# 12   Rus_f01  Female  Russia       Graduate   30
# 13   Rus_m01    Male  Russia       Graduate   32
# 14   Rus_f02  Female  Russia  Post Graduate   28
# 15   Rus_f03  Female  Russia       Graduate   34
# 16   Rus_m02    Male  Russia       Graduate   30
# 17   Rus_f04  Female  Russia  Post Graduate   36
# ...

# %%
pd.crosstab(index=df1['Country'],columns=df1['Gender'],margins=True)
# Out:
# Gender   Female  Male  All
# Country
# India         5     7   12
# Russia        4     3    7
# Usa           6     4   10
# All          15    14   29

# %%
pd.crosstab(index=df1['Gender'],columns=df1['Country'],margins=True)
# Out:
# Country  India  Russia  Usa  All
# Gender
# Female       5       4    6   15
# Male         7       3    4   14
# All         12       7   10   29

# %%
df1.head()
# Out:
#       Name  Gender Country         Degree  Age
# 0   Shanti  Female   India  Post Graduate   23
# 1    Naren    Male   India       Graduate   20
# 2    Kumar    Male   India       Graduate   27
# 3  Narayan    Male   India  Post Graduate   25
# 4    Shiva    Male   India       Graduate   28

# %%
pd.crosstab(index=df1['Gender'],columns=df1['Degree'],margins=True)
# Out:
# Degree  Graduate  Post Graduate  All
# Gender
# Female         7              8   15
# Male           9              5   14
# All           16             13   29

# %%
pd.crosstab(index=df1['Country'],columns=df1['Degree'],margins=True)
# Out:
# Degree   Graduate  Post Graduate  All
# Country
# India           6              6   12
# Russia          5              2    7
# Usa             5              5   10
# All            16             13   29

# %%
pd.crosstab(index=[df1['Country'],df1['Gender']],columns=df1['Degree'],margins=True)
# Out:
# Degree          Graduate  Post Graduate  All
# Country Gender
# India   Female         1              4    5
#         Male           5              2    7
# Russia  Female         2              2    4
#         Male           3              0    3
# Usa     Female         4              2    6
#         Male           1              3    4
# All                   16             13   29
