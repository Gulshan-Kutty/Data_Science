# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r'C:\Users\User\Downloads\hyd1_extrarow.csv')

# %%
df1
# Out:
#      Hyderabad Unnamed: 1
# 0         Date       Temp
# 1   21-01-2022         30
# 2   22-01-2022        NaN
# 3   23-01-2022        NaN
# 4   24-01-2022         29
# 5   25-01-2022        NaN
# 6   26-01-2022         32
# 7   27-01-2022        NaN
# 8   28-01-2022        NaN
# 9   29-01-2022        NaN
# 10  30-01-2022         38
# 11  31-01-2022         36

# %%
df1=pd.read_csv(r'C:\Users\User\Downloads\hyd1_extrarow.csv',header=1) # first row is skipped off

# %%
df1
# Out:
#           Date  Temp
# 0   21-01-2022  30.0
# 1   22-01-2022   NaN
# 2   23-01-2022   NaN
# 3   24-01-2022  29.0
# 4   25-01-2022   NaN
# 5   26-01-2022  32.0
# 6   27-01-2022   NaN
# 7   28-01-2022   NaN
# 8   29-01-2022   NaN
# 9   30-01-2022  38.0
# 10  31-01-2022  36.0

# %%
df1=pd.read_csv(r'C:\Users\User\Downloads\hyd1_extrarow.csv',skiprows=1) # first row is skipped off

# %%
df1
# Out:
#           Date  Temp
# 0   21-01-2022  30.0
# 1   22-01-2022   NaN
# 2   23-01-2022   NaN
# 3   24-01-2022  29.0
# 4   25-01-2022   NaN
# 5   26-01-2022  32.0
# 6   27-01-2022   NaN
# 7   28-01-2022   NaN
# 8   29-01-2022   NaN
# 9   30-01-2022  38.0
# 10  31-01-2022  36.0

# %%
# when we have no column names(labels), then give header=None

# %%
df2=pd.read_csv(r'C:\Users\User\Downloads\std_data1_no labels.csv')

# %%
df2
# Out:
#    A  10  67  66  66.1
# 0  B  12  87  56    65
# 1  C  11  66  89    63
# 2  D  10  56  88    66
# 3  E  10  89  90    56
# 4  F   9  88  85    89
# 5  G  12  90  83    88
# 6  H  11  79  88    90

# %%
df2=pd.read_csv(r'C:\Users\User\Downloads\std_data1_no labels.csv',header=None)

# %%
df2
# Out:
#    0   1   2   3   4
# 0  A  10  67  66  66
# 1  B  12  87  56  65
# 2  C  11  66  89  63
# 3  D  10  56  88  66
# 4  E  10  89  90  56
# 5  F   9  88  85  89
# 6  G  12  90  83  88
# 7  H  11  79  88  90

# %%
df2=pd.read_csv(r'C:\Users\User\Downloads\std_data1_no labels.csv',header=None,names=['Name','Class','Eng','sci','Comp'])

# %%
df2
# Out:
#   Name  Class  Eng  sci  Comp
# 0    A     10   67   66    66
# 1    B     12   87   56    65
# 2    C     11   66   89    63
# 3    D     10   56   88    66
# 4    E     10   89   90    56
# 5    F      9   88   85    89
# 6    G     12   90   83    88
# 7    H     11   79   88    90

# %%
df2=pd.read_csv(r'C:\Users\User\Downloads\std_data1_no labels.csv')

# %%
df2.columns=['Name','Class','Eng','sci','Comp']

# %%
df2
# Out:
#   Name  Class  Eng  sci  Comp
# 0    B     12   87   56    65
# 1    C     11   66   89    63
# 2    D     10   56   88    66
# 3    E     10   89   90    56
# 4    F      9   88   85    89
# 5    G     12   90   83    88
# 6    H     11   79   88    90

# %%
df3=pd.read_csv(r'C:\Users\User\Downloads\std_data1.csv')

# %%
df3
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df3=pd.read_csv(r'C:\Users\User\Downloads\std_data1.csv',nrows=5)

# %%
df3
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56

# %%
df3.head(3) # by default it gives first five rows  for df3.head()
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63

# %%
df3
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56

# %%
df3.tail(3) # by default it gives last five rows for df3.tail()
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56

# %%
df3
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56

# %%
df3.sample(2) # it gives random rows
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 2     C       11       66        89       63
# 0     A       10       67        66       66

# %%
df4=pd.read_csv(r'C:\Users\User\Downloads\std_data1.csv')

# %%
df4
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df4=pd.read_csv(r'C:\Users\User\Downloads\std_data1.csv',skiprows=[1,3,4])

# %%
df4
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     B       12       87        56       65
# 1     E       10       89        90       56
# 2     F        9       88        85       89
# 3     G       12       90        83       88
# 4     H       11       79        88       90

# %%
df5=pd.read_csv(r'C:\Users\User\Downloads\hyd_outlier.csv')

# %%
df5
# Out:
#           Date     Temp
# 0   21-01-2022     30.0
# 1   22-01-2022     28.0
# 2   23-01-2022   9999.0
# 3   24-01-2022     29.0
# 4   25-01-2022     31.0
# 5   26-01-2022     32.0
# 6   27-01-2022     34.0
# 7   28-01-2022     -1.0
# 8   29-01-2022     36.0
# 9   30-01-2022     38.0
# 10  31-01-2022      NaN
# 11  13-02-2022     25.0
# 12  14-02-2022   8989.0
# 13  15-02-2022     22.0
# 14  16-02-2022     21.0
# 15  17-02-2022      NaN
# 16  18-02-2022     22.0
# 17  19-02-2022  10101.0
# 18  20-02-2022     20.0

# %%
df5=pd.read_csv(r'C:\Users\User\Downloads\hyd_outlier.csv',na_values=[9999,-1,8989,10101])
# Rectifying outliers at the time of uploading data from csv file using read_csv.
# attribute 'na_values' is under the read_csv only.

# %%
df5
# Out:
#           Date  Temp
# 0   21-01-2022  30.0
# 1   22-01-2022  28.0
# 2   23-01-2022   NaN
# 3   24-01-2022  29.0
# 4   25-01-2022  31.0
# 5   26-01-2022  32.0
# 6   27-01-2022  34.0
# 7   28-01-2022   NaN
# 8   29-01-2022  36.0
# 9   30-01-2022  38.0
# 10  31-01-2022   NaN
# 11  13-02-2022  25.0
# 12  14-02-2022   NaN
# 13  15-02-2022  22.0
# 14  16-02-2022  21.0
# 15  17-02-2022   NaN
# 16  18-02-2022  22.0
# 17  19-02-2022   NaN
# 18  20-02-2022  20.0

# %%
d1={
    'Hyd':[35,36,-1,34,2],
    'Del':[32,-2,36,0,31],
    'Sri':[34,-1,0,2,-2]
}

# %%
dfind=pd.DataFrame(d1)

# %%
dfind
# Out:
#    Hyd  Del  Sri
# 0   35   32   34
# 1   36   -2   -1
# 2   -1   36    0
# 3   34    0    2
# 4    2   31   -2

# %%
# outliers
# Hyd---> -1,2
# Del---> -2,0
# Sri--->34

# %%
dfind.to_csv('Ind.csv') # Converted dfind to csv file

# %%
pd.read_csv('Ind.csv',na_values=[-1,2]) # every -1,2 values converted to NaN which is wrong as per state data
# Out:
#    Unnamed: 0   Hyd  Del   Sri
# 0         0.0  35.0   32  34.0
# 1         1.0  36.0   -2   NaN
# 2         NaN   NaN   36   0.0
# 3         3.0  34.0    0   NaN
# 4         4.0   NaN   31  -2.0

# %%
dfind
# Out:
#    Hyd  Del  Sri
# 0   35   32   34
# 1   36   -2   -1
# 2   -1   36    0
# 3   34    0    2
# 4    2   31   -2

# %%
dtemp={
    'Hyd':[-1,2],
    'Del':[-2,0],
    'Sri':[34]
}

# %%
pd.read_csv('Ind.csv',na_values=dtemp) # 'na_values' attribute is under read_csv only but not under dataframe
# Out:
#    Unnamed: 0   Hyd   Del  Sri
# 0           0  35.0  32.0  NaN
# 1           1  36.0   NaN -1.0
# 2           2   NaN  36.0  0.0
# 3           3  34.0   NaN  2.0
# 4           4   NaN  31.0 -2.0

# %%
d1={
    'Hyd':[35,36,-1,34,2],
    'Del':[32,-2,36,0,31],
    'Sri':[34,-1,0,2,-2]
}

# %%
dftemp=pd.DataFrame(d1)

# %%
dftemp
# Out:
#    Hyd  Del  Sri
# 0   35   32   34
# 1   36   -2   -1
# 2   -1   36    0
# 3   34    0    2
# 4    2   31   -2

# %%
dftemp.replace(-1,np.nan) # Rectifying outliers using attribute 'replace' boz we are having DataFrame but not csv file.
# Out:
#     Hyd  Del   Sri
# 0  35.0   32  34.0
# 1  36.0   -2   NaN
# 2   NaN   36   0.0
# 3  34.0    0   2.0
# 4   2.0   31  -2.0

# %%
dftemp.replace({
    'Hyd':[-1,2],
    'Del':[-2,0],
    'Sri':[34]
},np.nan)
# Out:
#     Hyd   Del  Sri
# 0  35.0  32.0  NaN
# 1  36.0   NaN -1.0
# 2   NaN  36.0  0.0
# 3  34.0   NaN  2.0
# 4   NaN  31.0 -2.0

# %%
# it's not necessary that always u will get data in the form of csv file,sometimes u may get data in DataFrame format
# so knowing both things is important

# %%
dfspeed=pd.read_csv(r'C:\Users\User\Downloads\DATASETS\replace\speed.csv')

# %%
dfspeed
# Out:
#          Date     Bajaj Price_india     Honda    Price Daytype
# 0  05-01-2021  135 kmph   Rs.150000  132 kmph  $1,500      Sun
# 1  05-02-2021  110 kmph   Rs.175000  112 kmph  $2,500    Windy
# 2  05-03-2021   98 kmph   Rs.150000   95 kmph  $3,500    Rainy
# 3  05-04-2021  105 kmph   Rs.200000  106 kmph  $2,500    Windy
# 4  05-05-2021  135 kmph   Rs.150000  133 kmph  $1,800      Sun
# 5  05-06-2021  140 kmph   Rs.100000  138 kmph  $2,500      Sun
# 6  05-07-2021  135 kmph   Rs.175000  138 kmph  $3,500      Sun
# 7  05-08-2021   90 kmph   Rs.100000   92 kmph  $2,500     Cold
# 8  05-09-2021   95 kmph   Rs.150007   93 kmph  $1,800     Cold
# 9  05-10-2021  100 kmph   Rs.175008   98 kmph  $1,500    Rainy

# %%
dfspeed["Price"].sum()
# Out:
# '$1,500 $2,500 $3,500 $2,500 $1,800 $2,500 $3,500 $2,500 $1,800 $1,500 '

# %%
dfspeed['Price']=dfspeed['Price'].replace('[$,]','',regex=True)

# %%
dfspeed
# Out:
#          Date     Bajaj Price_india     Honda  Price Daytype
# 0  05-01-2021  135 kmph   Rs.150000  132 kmph  1500      Sun
# 1  05-02-2021  110 kmph   Rs.175000  112 kmph  2500    Windy
# 2  05-03-2021   98 kmph   Rs.150000   95 kmph  3500    Rainy
# 3  05-04-2021  105 kmph   Rs.200000  106 kmph  2500    Windy
# 4  05-05-2021  135 kmph   Rs.150000  133 kmph  1800      Sun
# 5  05-06-2021  140 kmph   Rs.100000  138 kmph  2500      Sun
# 6  05-07-2021  135 kmph   Rs.175000  138 kmph  3500      Sun
# 7  05-08-2021   90 kmph   Rs.100000   92 kmph  2500     Cold
# 8  05-09-2021   95 kmph   Rs.150007   93 kmph  1800     Cold
# 9  05-10-2021  100 kmph   Rs.175008   98 kmph  1500    Rainy

# %%
dfspeed.dtypes
# Out:
# Date           object
# Bajaj          object
# Price_india    object
# Honda          object
# Price          object
# Daytype        object
# dtype: object

# %%
dfspeed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         10 non-null     object
#  1   Bajaj        10 non-null     object
#  2   Price_india  10 non-null     object
#  3   Honda        10 non-null     object
#  4   Price        10 non-null     object
#  5   Daytype      10 non-null     object
# dtypes: object(6)
# memory usage: 608.0+ bytes

# %%
dfspeed['Price']=dfspeed['Price'].astype('int')

# %%
dfspeed
# Out:
#          Date     Bajaj Price_india     Honda  Price Daytype
# 0  05-01-2021  135 kmph   Rs.150000  132 kmph   1500     Sun
# 1  05-02-2021  110 kmph   Rs.175000  112 kmph   2500   Windy
# 2  05-03-2021   98 kmph   Rs.150000   95 kmph   3500   Rainy
# 3  05-04-2021  105 kmph   Rs.200000  106 kmph   2500   Windy
# 4  05-05-2021  135 kmph   Rs.150000  133 kmph   1800     Sun
# 5  05-06-2021  140 kmph   Rs.100000  138 kmph   2500     Sun
# 6  05-07-2021  135 kmph   Rs.175000  138 kmph   3500     Sun
# 7  05-08-2021   90 kmph   Rs.100000   92 kmph   2500    Cold
# 8  05-09-2021   95 kmph   Rs.150007   93 kmph   1800    Cold
# 9  05-10-2021  100 kmph   Rs.175008   98 kmph   1500   Rainy

# %%
dfspeed.dtypes
# Out:
# Date           object
# Bajaj          object
# Price_india    object
# Honda          object
# Price           int32
# Daytype        object
# dtype: object

# %%
dfspeed['Price'].sum()
# Out:
# 23600

# %%
dfspeed['Price_india']=dfspeed['Price_india'].replace('[Rs.]','',regex=True).astype('int')

# %%
dfspeed
# Out:
#          Date     Bajaj  Price_india     Honda  Price Daytype
# 0  05-01-2021  135 kmph       150000  132 kmph   1500     Sun
# 1  05-02-2021  110 kmph       175000  112 kmph   2500   Windy
# 2  05-03-2021   98 kmph       150000   95 kmph   3500   Rainy
# 3  05-04-2021  105 kmph       200000  106 kmph   2500   Windy
# 4  05-05-2021  135 kmph       150000  133 kmph   1800     Sun
# 5  05-06-2021  140 kmph       100000  138 kmph   2500     Sun
# 6  05-07-2021  135 kmph       175000  138 kmph   3500     Sun
# 7  05-08-2021   90 kmph       100000   92 kmph   2500    Cold
# 8  05-09-2021   95 kmph       150007   93 kmph   1800    Cold
# 9  05-10-2021  100 kmph       175008   98 kmph   1500   Rainy

# %%
dfspeed['Honda']=dfspeed['Honda'].replace(' kmph','',regex=True).astype('int')

# %%
dfspeed.dtypes
# Out:
# Date           object
# Bajaj          object
# Price_india     int32
# Honda           int32
# Price           int32
# Daytype        object
# dtype: object

# %%
dfspeed['Bajaj']=dfspeed['Bajaj'].replace(' kmph','',regex=True).astype('int')

# %%
dfspeed.dtypes
# Out:
# Date           object
# Bajaj           int32
# Price_india     int32
# Honda           int32
# Price           int32
# Daytype        object
# dtype: object

# %%
dfspeed["Date"]
# Out:
# 0    05-01-2021
# 1    05-02-2021
# 2    05-03-2021
# 3    05-04-2021
# 4    05-05-2021
# 5    05-06-2021
# 6    05-07-2021
# 7    05-08-2021
# 8    05-09-2021
# 9    05-10-2021
# Name: Date, dtype: object

# %%
type(dfspeed['Date'])
# Out:
# pandas.core.series.Series

# %%
type(dfspeed['Date'][0])
# Out:
# str

# %%
dfspeed['Date']
# Out:
# 0    05-01-2021
# 1    05-02-2021
# 2    05-03-2021
# 3    05-04-2021
# 4    05-05-2021
# 5    05-06-2021
# 6    05-07-2021
# 7    05-08-2021
# 8    05-09-2021
# 9    05-10-2021
# Name: Date, dtype: object

# %%
dfspeed['Date']=pd.to_datetime(dfspeed['Date'])

# %%
dfspeed
# Out:
#         Date  Bajaj  Price_india  Honda  Price Daytype
# 0 2021-05-01    135       150000    132   1500     Sun
# 1 2021-05-02    110       175000    112   2500   Windy
# 2 2021-05-03     98       150000     95   3500   Rainy
# 3 2021-05-04    105       200000    106   2500   Windy
# 4 2021-05-05    135       150000    133   1800     Sun
# 5 2021-05-06    140       100000    138   2500     Sun
# 6 2021-05-07    135       175000    138   3500     Sun
# 7 2021-05-08     90       100000     92   2500    Cold
# 8 2021-05-09     95       150007     93   1800    Cold
# 9 2021-05-10    100       175008     98   1500   Rainy

# %%
dfspeed.dtypes
# Out:
# Date           datetime64[ns]
# Bajaj                   int32
# Price_india             int32
# Honda                   int32
# Price                   int32
# Daytype                object
# dtype: object

# %%
dfspeed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         10 non-null     datetime64[ns]
#  1   Bajaj        10 non-null     int32
#  2   Price_india  10 non-null     int32
#  3   Honda        10 non-null     int32
#  4   Price        10 non-null     int32
#  5   Daytype      10 non-null     object
# dtypes: datetime64[ns](1), int32(4), object(1)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### some date format conversion examples

# %%
pd.to_datetime('20/12/22')
# Out:
# Timestamp('2022-12-20 00:00:00')

# %%
pd.to_datetime('20.Dec.22')
# Out:
# Timestamp('2022-12-20 00:00:00')
