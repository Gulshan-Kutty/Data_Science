# %%
import numpy as np
import pandas as pd

# %%
d1={
    'City':['Del','Jpur','Lnow','Simla'],
    'Temp':[35,38,34,25]
}

# %%
d2={
    'City':['Hyd','Blr','Che','Vizag'],
    'Temp':[35,32,38,36]
}

# %%
d3={
    'City':['A','B','C','D'],
    'Temp':[35,38,34,25]
}

# %%
d4={
    'City':['X','Y','Z','W'],
    'Temp':[35,38,34,25]
}

# %%
dfnorth=pd.DataFrame(d1)

# %%
dfsouth=pd.DataFrame(d2)

# %%
dfnorth
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25

# %%
dfsouth
# Out:
#     City  Temp
# 0    Hyd    35
# 1    Blr    32
# 2    Che    38
# 3  Vizag    36

# %%
dfcity=pd.concat([dfnorth,dfsouth])

# %%
dfcity # internally index will be 0,1,2,3,4,5,6,7
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25
# 0    Hyd    35
# 1    Blr    32
# 2    Che    38
# 3  Vizag    36

# %%
dfcity.iloc[0]
# Out:
# City    Del
# Temp     35
# Name: 0, dtype: object

# %%
dfcity.iloc[4]
# Out:
# City    Hyd
# Temp     35
# Name: 0, dtype: object

# %%
dfcity.loc[0]
# Out:
#   City  Temp
# 0  Del    35
# 0  Hyd    35

# %%
dfcity
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25
# 0    Hyd    35
# 1    Blr    32
# 2    Che    38
# 3  Vizag    36

# %%
dfcity.iloc[5]
# Out:
# City    Blr
# Temp     32
# Name: 1, dtype: object

# %%
dfcity.loc[2]
# Out:
#    City  Temp
# 2  Lnow    34
# 2   Che    38

# %%
dfcity
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25
# 0    Hyd    35
# 1    Blr    32
# 2    Che    38
# 3  Vizag    36

# %%
dfindia=pd.concat([dfnorth,dfsouth],ignore_index=True)

# %%
dfindia
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25
# 4    Hyd    35
# 5    Blr    32
# 6    Che    38
# 7  Vizag    36

# %%
dfcity
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25
# 0    Hyd    35
# 1    Blr    32
# 2    Che    38
# 3  Vizag    36

# %%
dfcity.reset_index()
# Out:
#    index   City  Temp
# 0      0    Del    35
# 1      1   Jpur    38
# 2      2   Lnow    34
# 3      3  Simla    25
# 4      0    Hyd    35
# 5      1    Blr    32
# 6      2    Che    38
# 7      3  Vizag    36

# %%
dfcity.reset_index().drop('index',axis=1)
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25
# 4    Hyd    35
# 5    Blr    32
# 6    Che    38
# 7  Vizag    36

# %%
df2=pd.concat([dfnorth,dfsouth],keys=['North','South'])

# %%
df2
# Out:
#           City  Temp
# North 0    Del    35
#       1   Jpur    38
#       2   Lnow    34
#       3  Simla    25
# South 0    Hyd    35
#       1    Blr    32
#       2    Che    38
#       3  Vizag    36

# %%
df2['Temp'].mean()
# Out:
# 34.125

# %%
df2.loc['North']['Temp'].mean()
# Out:
# 33.0

# %%
dfnorth
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25

# %%
dfsouth
# Out:
#     City  Temp
# 0    Hyd    35
# 1    Blr    32
# 2    Che    38
# 3  Vizag    36

# %%
dfeast=pd.DataFrame(d3)

# %%
dfwest=pd.DataFrame(d4)

# %%
dfnorth
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25

# %%
dfsouth
# Out:
#     City  Temp
# 0    Hyd    35
# 1    Blr    32
# 2    Che    38
# 3  Vizag    36

# %%
dfeast
# Out:
#   City  Temp
# 0    A    35
# 1    B    38
# 2    C    34
# 3    D    25

# %%
dfwest
# Out:
#   City  Temp
# 0    X    35
# 1    Y    38
# 2    Z    34
# 3    W    25

# %%
dfind=pd.concat([dfnorth,dfsouth,dfeast,dfwest],keys=['North','South','East','West'])

# %%
dfind
# Out:
#           City  Temp
# North 0    Del    35
#       1   Jpur    38
#       2   Lnow    34
#       3  Simla    25
# South 0    Hyd    35
#       1    Blr    32
#       2    Che    38
#       3  Vizag    36
# East  0      A    35
#       1      B    38
#       2      C    34
#       3      D    25
# West  0      X    35
#       1      Y    38
#       2      Z    34
#       3      W    25

# %%
dfind['Temp'].mean()
# Out:
# 33.5625

# %%
dfind.loc['East']['Temp'].mean()
# Out:
# 33.0

# %%
ds1={
    'City':['Del','Jpur','Lnow','Simla'],
    'Temp':[35,38,34,25]
}

# %%
ds2={
    'City':['Del','Jpur','Lnow','Simla'],
    'Humid':[35,32,38,36]
}

# %%
dftemp=pd.DataFrame(ds1)

# %%
dfhumid=pd.DataFrame(ds2)

# %%
dftemp
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25

# %%
dfhumid
# Out:
#     City  Humid
# 0    Del     35
# 1   Jpur     32
# 2   Lnow     38
# 3  Simla     36

# %%
pd.concat([dftemp,dfhumid])
# Out:
#     City  Temp  Humid
# 0    Del  35.0    NaN
# 1   Jpur  38.0    NaN
# 2   Lnow  34.0    NaN
# 3  Simla  25.0    NaN
# 0    Del   NaN   35.0
# 1   Jpur   NaN   32.0
# 2   Lnow   NaN   38.0
# 3  Simla   NaN   36.0

# %%
pd.concat([dftemp,dfhumid],axis=1)
# Out:
#     City  Temp   City  Humid
# 0    Del    35    Del     35
# 1   Jpur    38   Jpur     32
# 2   Lnow    34   Lnow     38
# 3  Simla    25  Simla     36

# %%
dftemp
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25

# %%
dfhumid
# Out:
#     City  Humid
# 0    Del     35
# 1   Jpur     32
# 2   Lnow     38
# 3  Simla     36

# %%
dftemp=dftemp.set_index('City')

# %%
dftemp
# Out:
#        Temp
# City
# Del      35
# Jpur     38
# Lnow     34
# Simla    25

# %%
dfhumid=dfhumid.set_index('City')

# %%
dfhumid
# Out:
#        Humid
# City
# Del       35
# Jpur      32
# Lnow      38
# Simla     36

# %%
display(dftemp,dfhumid)
# Out:
#        Temp
# City
# Del      35
# Jpur     38
# Lnow     34
# Simla    25
#        Humid
# City
# Del       35
# Jpur      32
# Lnow      38
# Simla     36

# %%
dffinal=pd.concat([dftemp,dfhumid],axis=1)

# %%
dffinal
# Out:
#        Temp  Humid
# City
# Del      35     35
# Jpur     38     32
# Lnow     34     38
# Simla    25     36

# %%
dffinal=dffinal.reset_index()

# %%
dffinal
# Out:
#     City  Temp  Humid
# 0    Del    35     35
# 1   Jpur    38     32
# 2   Lnow    34     38
# 3  Simla    25     36

# %%
ds1 = {'City': ["Del", 'Jpur', 'Lnow', 'Simla',"Mum","Pune"],
     'Temp': [35, 38, 34, 25,32,34]}
ds2 = {'City': ["Del", 'Jpur', 'Lnow', 'Simla'],
    'Humid': [35, 38, 34, 25]}

# %%
dfstemp=pd.DataFrame(ds1)

# %%
dfshumid=pd.DataFrame(ds2)

# %%
dfstemp
# Out:
#     City  Temp
# 0    Del    35
# 1   Jpur    38
# 2   Lnow    34
# 3  Simla    25
# 4    Mum    32
# 5   Pune    34

# %%
dfshumid
# Out:
#     City  Humid
# 0    Del     35
# 1   Jpur     38
# 2   Lnow     34
# 3  Simla     25

# %%
pd.concat([dfstemp,dfshumid],axis=1) # by default join='outer'
# Out:
#     City  Temp   City  Humid
# 0    Del    35    Del   35.0
# 1   Jpur    38   Jpur   38.0
# 2   Lnow    34   Lnow   34.0
# 3  Simla    25  Simla   25.0
# 4    Mum    32    NaN    NaN
# 5   Pune    34    NaN    NaN

# %%
pd.concat([dfstemp,dfshumid],axis=1,join='inner')
# Out:
#     City  Temp   City  Humid
# 0    Del    35    Del     35
# 1   Jpur    38   Jpur     38
# 2   Lnow    34   Lnow     34
# 3  Simla    25  Simla     25

# %%
dss1 = {'City': ["Del", 'Jpur', 'Lnow', 'Simla'],
       "State":["DL", 'RS', 'UP', 'WB'],
     'Temp': [35, 38, 34, 25]}
dss2 = {'City': ["Del", 'Jpur', 'Lnow', 'Simla'],
    "State":["DL", 'RS', 'UP', 'WB'],
    'Humid': [31, 32, 33, 36]}

# %%
dftem=pd.DataFrame(dss1)

# %%
dfhum=pd.DataFrame(dss2)

# %%
dftem
# Out:
#     City State  Temp
# 0    Del    DL    35
# 1   Jpur    RS    38
# 2   Lnow    UP    34
# 3  Simla    WB    25

# %%
dfhum
# Out:
#     City State  Humid
# 0    Del    DL     31
# 1   Jpur    RS     32
# 2   Lnow    UP     33
# 3  Simla    WB     36

# %%
dfth=pd.merge(dftemp,dfhumid,on='City')

# %%
dfth
# Out:
#        Temp  Humid
# City
# Del      35     35
# Jpur     38     32
# Lnow     34     38
# Simla    25     36

# %%
dfth.reset_index('City')
# Out:
#     City  Temp  Humid
# 0    Del    35     35
# 1   Jpur    38     32
# 2   Lnow    34     38
# 3  Simla    25     36

# %%
# incomplete

# %%
dic1={
    "ID":[1,2,3,4,8,9],
    "Eng":[55,78,87,90,69,56]
}
dic2={
    "ID":[1,2,3,4,5,6,7],
    "Comp":[56,77,88,98,61,58,85]
}

# %%
dfeng=pd.DataFrame(dic1)

# %%
dfcomp=pd.DataFrame(dic2)

# %%
dfeng
# Out:
#    ID  Eng
# 0   1   55
# 1   2   78
# 2   3   87
# 3   4   90
# 4   8   69
# 5   9   56

# %%
dfcomp
# Out:
#    ID  Comp
# 0   1    56
# 1   2    77
# 2   3    88
# 3   4    98
# 4   5    61
# 5   6    58
# 6   7    85

# %%
pd.merge(dfeng,dfcomp,left_index=True,right_index=True,suffixes=["_left","_right"])
# Out:
#    ID_left  Eng  ID_right  Comp
# 0        1   55         1    56
# 1        2   78         2    77
# 2        3   87         3    88
# 3        4   90         4    98
# 4        8   69         5    61
# 5        9   56         6    58

# %%
dfeng1=pd.DataFrame(dic1)
dfcomp1=pd.DataFrame(dic2)

# %%
display(dfeng1,dfcomp1)
# Out:
#    ID  Eng
# 0   1   55
# 1   2   78
# 2   3   87
# 3   4   90
# 4   8   69
# 5   9   56
#    ID  Comp
# 0   1    56
# 1   2    77
# 2   3    88
# 3   4    98
# 4   5    61
# 5   6    58
# 6   7    85

# %%
pd.merge(dfeng1,dfcomp1, how= "outer")
# Out:
#    ID   Eng  Comp
# 0   1  55.0  56.0
# 1   2  78.0  77.0
# 2   3  87.0  88.0
# 3   4  90.0  98.0
# 4   8  69.0   NaN
# 5   9  56.0   NaN
# 6   5   NaN  61.0
# 7   6   NaN  58.0
# 8   7   NaN  85.0

# %%
pd.merge(dfeng1,dfcomp1, how= "outer",indicator=True)
# Out:
#    ID   Eng  Comp      _merge
# 0   1  55.0  56.0        both
# 1   2  78.0  77.0        both
# 2   3  87.0  88.0        both
# 3   4  90.0  98.0        both
# 4   8  69.0   NaN   left_only
# 5   9  56.0   NaN   left_only
# 6   5   NaN  61.0  right_only
# 7   6   NaN  58.0  right_only
# 8   7   NaN  85.0  right_only

# %%
pd.merge(dfeng1,dfcomp1, how= "inner")
# Out:
#    ID  Eng  Comp
# 0   1   55    56
# 1   2   78    77
# 2   3   87    88
# 3   4   90    98

# %%
pd.merge(dfeng1,dfcomp1, how= "left")
# Out:
#    ID  Eng  Comp
# 0   1   55  56.0
# 1   2   78  77.0
# 2   3   87  88.0
# 3   4   90  98.0
# 4   8   69   NaN
# 5   9   56   NaN

# %%
pd.merge(dfeng1,dfcomp1, how= "right")
# Out:
#    ID   Eng  Comp
# 0   1  55.0    56
# 1   2  78.0    77
# 2   3  87.0    88
# 3   4  90.0    98
# 4   5   NaN    61
# 5   6   NaN    58
# 6   7   NaN    85
