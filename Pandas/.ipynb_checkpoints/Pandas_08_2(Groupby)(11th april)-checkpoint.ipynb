# %%
import pandas as pd
import numpy as np

# %%
dfgen=pd.read_csv(r'C:\Users\User\Downloads\DATASETS\Groupby\Gb_gender.csv')

# %%
dfgen
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %% [markdown]
# ## Groupby on Gender

# %%
gbobj=dfgen.groupby('Gender')

# %%
gbobj

# %%
gbobj.groups
# Out:
# {'Female': [1, 2, 6, 7, 8, 10, 12, 13, 17, 18, 19, 21, 22, 28, 29, 30, 32, 34, 35, 39, 40, 41, 42, 44, 46, 47, 51, 52, 53, 55, 56, 62, 63, 64, 66, 68, 70, 71, 73, 75, 76, 78], 'Male': [0, 3, 4, 5, 9, 11, 14, 15, 16, 20, 23, 24, 25, 26, 27, 31, 33, 36, 37, 38, 43, 45, 48, 49, 50, 54, 57, 58, 59, 60, 61, 65, 67, 69, 72, 74, 77, 79, 80]}

# %%
dfgen.head()
# Out:
#    Gender  Degree  Height       City
# 0    Male    B.Sc     174  Hyderabad
# 1  Female  B.Tech     167    Chennai
# 2  Female     B.E     169      Vizag
# 3    Male   B.Com     173      Delhi
# 4    Male     MBA     177     Jaipur

# %%
for x in gbobj:
    print(x)
# Out:
# ('Female',     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# ...

# %%
for x,y in gbobj: # x represents male,female and y represents values
    print(x)
    print(y)
# Out:
# Female
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# ...

# %%
dffemale=gbobj.get_group('Female')

# %%
dffemale
# Out:
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# ...

# %%
dffemale['Height']
# Out:
# 1     167
# 2     169
# 6     172
# 7     172
# 8     179
# 10    173
# 12    174
# 13    168
# 17    178
# 18    175
# 19    177
# 21    171
# 22    167
# 28    172
# 29    172
# 30    166
# 32    176
# 34    168
# 35    166
# 39    175
# 40    177
# 41    171
# 42    173
# 44    178
# 46    172
# 47    179
# 51    174
# 52    168
# 53    166
# 55    166
# 56    178
# 62    173
# 63    175
# 64    173
# 66    178
# 68    172
# 70    179
# 71    175
# 73    179
# 75    179
# 76    176
# 78    178
# Name: Height, dtype: int64

# %%
dffemale['Height'].max()
# Out:
# 179

# %%
ft=dffemale['Height']==179

# %%
dfsel1=dffemale[ft]

# %%
dfsel1
# Out:
#     Gender  Degree  Height       City
# 8   Female    B.Sc     179  Bangalore
# 47  Female    M.Sc     179      Delhi
# 70  Female  M.Tech     179  Hyderabad
# 73  Female     MBA     179     Bhopal
# 75  Female  M.Tech     179      Vizag

# %%
dfmale=gbobj.get_group('Male')

# %%
dfmale['Height']
# Out:
# 0     174
# 3     173
# 4     177
# 5     178
# 9     166
# 11    176
# 14    166
# 15    175
# 16    166
# 20    171
# 23    173
# 24    175
# 25    173
# 26    177
# 27    178
# 31    173
# 33    174
# 36    175
# 37    166
# 38    178
# 43    177
# 45    172
# 48    166
# 49    173
# 50    176
# 54    175
# 57    175
# 58    177
# 59    171
# 60    171
# 61    167
# 65    177
# 67    172
# 69    177
# 72    178
# 74    178
# 77    178
# 79    174
# 80    175
# Name: Height, dtype: int64

# %%
dfmale['Height'].max()
# Out:
# 178

# %%
dfmale["Height"]==dfmale['Height'].max()
# Out:
# 0     False
# 3     False
# 4     False
# 5      True
# 9     False
# 11    False
# 14    False
# 15    False
# 16    False
# 20    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 31    False
# 33    False
# 36    False
# 37    False
# 38     True
# 43    False
# 45    False
# 48    False
# 49    False
# 50    False
# 54    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 65    False
# 67    False
# 69    False
# 72     True
# 74     True
# 77     True
# 79    False
# 80    False
# Name: Height, dtype: bool

# %%
dfmale[dfmale["Height"]==dfmale['Height'].max()]
# Out:
#    Gender Degree  Height        City
# 5    Male   M.Sc     178  Chandigarh
# 27   Male   M.Sc     178  Chandigarh
# 38   Male  B.Com     178      Bhopal
# 72   Male  B.Com     178      Jaipur
# 74   Male   M.Sc     178       Vizag
# 77   Male    MCA     178     Chennai

# %%
dfsel2=dfmale[dfmale["Height"]==dfmale['Height'].max()]

# %%
dfsel2
# Out:
#    Gender Degree  Height        City
# 5    Male   M.Sc     178  Chandigarh
# 27   Male   M.Sc     178  Chandigarh
# 38   Male  B.Com     178      Bhopal
# 72   Male  B.Com     178      Jaipur
# 74   Male   M.Sc     178       Vizag
# 77   Male    MCA     178     Chennai

# %%
dfselected=pd.concat([dfsel1,dfsel2])

# %%
dfselected
# Out:
#     Gender  Degree  Height        City
# 8   Female    B.Sc     179   Bangalore
# 47  Female    M.Sc     179       Delhi
# 70  Female  M.Tech     179   Hyderabad
# 73  Female     MBA     179      Bhopal
# 75  Female  M.Tech     179       Vizag
# 5     Male    M.Sc     178  Chandigarh
# 27    Male    M.Sc     178  Chandigarh
# 38    Male   B.Com     178      Bhopal
# 72    Male   B.Com     178      Jaipur
# 74    Male    M.Sc     178       Vizag
# 77    Male     MCA     178     Chennai

# %% [markdown]
# ## Groupby on City

# %%
dfgen
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %%
dfgen=dfgen[['City','Gender','Degree','Height']]

# %%
dfgen
# Out:
#           City  Gender  Degree  Height
# 0    Hyderabad    Male    B.Sc     174
# 1      Chennai  Female  B.Tech     167
# 2        Vizag  Female     B.E     169
# 3        Delhi    Male   B.Com     173
# 4       Jaipur    Male     MBA     177
# ..         ...     ...     ...     ...
# 76   Hyderabad  Female    B.Sc     176
# 77     Chennai    Male     MCA     178
# 78   Hyderabad  Female    B.Sc     178
# 79  Chandigarh    Male  B.Tech     174
# 80     Lucknow    Male  M.Tech     175
#
# [81 rows x 4 columns]

# %%
gbcity=dfgen.groupby('City')

# %%
for x,y in gbcity:
    print(x)
    print(y)
# Out:
# Bangalore
#          City  Gender Degree  Height
# 8   Bangalore  Female   B.Sc     179
# 23  Bangalore    Male    B.E     173
# 30  Bangalore  Female   B.Sc     166
# 45  Bangalore    Male  B.Com     172
# 52  Bangalore  Female   M.Sc     168
# 58  Bangalore    Male  B.Com     177
# Bhopal
#       City  Gender  Degree  Height
# 7   Bhopal  Female     MCA     172
# 16  Bhopal    Male   B.Com     166
# 22  Bhopal  Female  B.Tech     167
# 29  Bhopal  Female     MCA     172
# 38  Bhopal    Male   B.Com     178
# 44  Bhopal  Female     B.E     178
# 51  Bhopal  Female     MBA     174
# 65  Bhopal    Male  B.Tech     177
# 69  Bhopal    Male    M.Sc     177
# 73  Bhopal  Female     MBA     179
# Chandigarh
#           City  Gender  Degree  Height
# 5   Chandigarh    Male    M.Sc     178
# 14  Chandigarh    Male  M.Tech     166
# 20  Chandigarh    Male     MCA     171
# 27  Chandigarh    Male    M.Sc     178
# 36  Chandigarh    Male  M.Tech     175
# ...

# %%
dfgen.City.unique()
# Out:
# array(['Hyderabad', 'Chennai', 'Vizag', 'Delhi', 'Jaipur', 'Chandigarh',
#        'Lucknow', 'Bhopal', 'Bangalore'], dtype=object)

# %%
dfhyd=gbcity.get_group('Hyderabad')

# %%
dfhyd
# Out:
#          City  Gender  Degree  Height
# 0   Hyderabad    Male    B.Sc     174
# 9   Hyderabad    Male  B.Tech     166
# 24  Hyderabad    Male   B.Com     175
# 31  Hyderabad    Male  B.Tech     173
# 46  Hyderabad  Female     MBA     172
# 53  Hyderabad  Female  M.Tech     166
# 59  Hyderabad    Male   B.Com     171
# 60  Hyderabad    Male     MBA     171
# 66  Hyderabad  Female     B.E     178
# 68  Hyderabad  Female     MBA     172
# 70  Hyderabad  Female  M.Tech     179
# 76  Hyderabad  Female    B.Sc     176
# 78  Hyderabad  Female    B.Sc     178

# %%
dfhyd['Height'].max()
# Out:
# 179

# %%
dfhyd['Height']==179 # or dfhyd['Height]==dfhyd['Height'].max()
# Out:
# 0     False
# 9     False
# 24    False
# 31    False
# 46    False
# 53    False
# 59    False
# 60    False
# 66    False
# 68    False
# 70     True
# 76    False
# 78    False
# Name: Height, dtype: bool

# %%
dfhyd[dfhyd['Height']==179]
# Out:
#          City  Gender  Degree  Height
# 70  Hyderabad  Female  M.Tech     179

# %%
dfsel1=dfhyd[dfhyd['Height']==179] # or dfsel1=dfhyd[dfhyd['Height']==dfhyd['Height'].max()]

# %%
dfsel1
# Out:
#          City  Gender  Degree  Height
# 70  Hyderabad  Female  M.Tech     179

# %%
dfche=gbcity.get_group('Chennai')

# %%
dfche
# Out:
#        City  Gender  Degree  Height
# 1   Chennai  Female  B.Tech     167
# 10  Chennai  Female     B.E     173
# 32  Chennai  Female     B.E     176
# 54  Chennai    Male     MCA     175
# 67  Chennai    Male   B.Com     172
# 77  Chennai    Male     MCA     178

# %%
dfsel2=dfche[dfche['Height']==dfche['Height'].max()]

# %%
dfsel2
# Out:
#        City Gender Degree  Height
# 77  Chennai   Male    MCA     178

# %%
# similarly do for all remaining cities and concat them at last

# %% [markdown]
# ## Groupby on two columns

# %%
dfgen
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %%
gbobj2=dfgen.groupby(['Gender','City'])

# %%
for x,y in gbobj2:
    print(x)
    print(y)
# Out:
# ('Female', 'Bangalore')
#     Gender Degree  Height       City
# 8   Female   B.Sc     179  Bangalore
# 30  Female   B.Sc     166  Bangalore
# 52  Female   M.Sc     168  Bangalore
# ('Female', 'Bhopal')
#     Gender  Degree  Height    City
# 7   Female     MCA     172  Bhopal
# 22  Female  B.Tech     167  Bhopal
# 29  Female     MCA     172  Bhopal
# 44  Female     B.E     178  Bhopal
# 51  Female     MBA     174  Bhopal
# 73  Female     MBA     179  Bhopal
# ('Female', 'Chandigarh')
#     Gender Degree  Height        City
# 42  Female   B.Sc     173  Chandigarh
# 63  Female    MCA     175  Chandigarh
# ('Female', 'Chennai')
#     Gender  Degree  Height     City
# 1   Female  B.Tech     167  Chennai
# 10  Female     B.E     173  Chennai
# 32  Female     B.E     176  Chennai
# ('Female', 'Delhi')
#     Gender  Degree  Height   City
# 12  Female     MBA     174  Delhi
# 18  Female    M.Sc     175  Delhi
# 34  Female     MBA     168  Delhi
# 40  Female    M.Sc     177  Delhi
# ...

# %%
gbobj3=dfgen.groupby(['City','Gender'])

# %%
for x,y in gbobj3:
    print(x)
    print(y)
# Out:
# ('Bangalore', 'Female')
#     Gender Degree  Height       City
# 8   Female   B.Sc     179  Bangalore
# 30  Female   B.Sc     166  Bangalore
# 52  Female   M.Sc     168  Bangalore
# ('Bangalore', 'Male')
#    Gender Degree  Height       City
# 23   Male    B.E     173  Bangalore
# 45   Male  B.Com     172  Bangalore
# 58   Male  B.Com     177  Bangalore
# ('Bhopal', 'Female')
#     Gender  Degree  Height    City
# 7   Female     MCA     172  Bhopal
# 22  Female  B.Tech     167  Bhopal
# 29  Female     MCA     172  Bhopal
# 44  Female     B.E     178  Bhopal
# 51  Female     MBA     174  Bhopal
# 73  Female     MBA     179  Bhopal
# ('Bhopal', 'Male')
#    Gender  Degree  Height    City
# 16   Male   B.Com     166  Bhopal
# 38   Male   B.Com     178  Bhopal
# 65   Male  B.Tech     177  Bhopal
# 69   Male    M.Sc     177  Bhopal
# ('Chandigarh', 'Female')
#     Gender Degree  Height        City
# 42  Female   B.Sc     173  Chandigarh
# 63  Female    MCA     175  Chandigarh
# ...

# %%
gbobj3.max()
# Out:
#                    Degree  Height
# City       Gender
# Bangalore  Female    M.Sc     179
#            Male       B.E     177
# Bhopal     Female     MCA     179
#            Male      M.Sc     178
# Chandigarh Female     MCA     175
#            Male       MCA     178
# Chennai    Female  B.Tech     176
#            Male       MCA     178
# Delhi      Female     MCA     179
#            Male     B.Com     173
# Hyderabad  Female     MBA     179
#            Male       MBA     175
# Jaipur     Female  M.Tech     177
#            Male       MBA     178
# Lucknow    Female  M.Tech     173
#            Male       MCA     177
# Vizag      Female     MBA     179
#            Male      M.Sc     178

# %%
dfsales=pd.read_csv(r'C:\Users\User\Downloads\DATASETS\Groupby\gbsales.csv')

# %%
dfsales
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
dfsales.drop('Status',axis=1,inplace=True)

# %%
dfsales
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
dfsales['Manager'].unique()
# Out:
# array(['Debra Henley', 'Fred Anderson'], dtype=object)

# %%
m=['Debra Henley', 'Fred Anderson']

# %%
for i in m:
    print(i)
# Out:
# Debra Henley
# Fred Anderson

# %%
for x in m:
    ft1=dfsales['Manager']==x
    print(dfsales[ft1])
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
# 5   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 6   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 7   412290                 Jerde-Hilpert     John Smith  Debra Henley
# 8   740150                    Barton LLC     John Smith  Debra Henley
#
#        Product  Quantity  Price
# 0          CPU         1  30000
# 1     Software         1  10000
# 2  Maintenance         2   5000
# 3          CPU         1  35000
# 4          CPU         2  65000
# 5          CPU         2  40000
# 6     Software         1  10000
# ...

# %%
#OR

# %%
gbmanager=dfsales.groupby('Manager')

# %%
for i,j in gbmanager:
    print(i)
    print(j)
# Out:
# Debra Henley
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
# 5   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 6   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 7   412290                 Jerde-Hilpert     John Smith  Debra Henley
# 8   740150                    Barton LLC     John Smith  Debra Henley
#
#        Product  Quantity  Price
# 0          CPU         1  30000
# 1     Software         1  10000
# 2  Maintenance         2   5000
# 3          CPU         1  35000
# 4          CPU         2  65000
# 5          CPU         2  40000
# ...

# %%
gbmanager.get_group('Debra Henley')
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
# 5   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 6   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 7   412290                 Jerde-Hilpert     John Smith  Debra Henley
# 8   740150                    Barton LLC     John Smith  Debra Henley
#
#        Product  Quantity  Price
# 0          CPU         1  30000
# 1     Software         1  10000
# 2  Maintenance         2   5000
# 3          CPU         1  35000
# 4          CPU         2  65000
# 5          CPU         2  40000
# 6     Software         1  10000
# ...

# %%
gbmanager.get_group('Debra Henley')['Price'].sum()
# Out:
# 235000
