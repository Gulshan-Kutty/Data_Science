# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("C:/Users/ajjup/OneDrive/Desktop/DATASETS/DATASETS/Melt/meltdb.csv ")

# %%
df1
# Out:
#     WeekDays  Hyderabad  Delhi  Vizag  Chennai
# 0     Monday         35     34     38       39
# 1    Tuesday         36     32     37       38
# 2  Wednesday         33     31     35       37
# 3   Thursday         35     33     36       38
# 4     Friday         38     35     38       37
# 5   Saturday         37     32     37       35
# 6     Sunday         35     33     35       36

# %%
pd.melt(df1)
# Out:
#      variable      value
# 0    WeekDays     Monday
# 1    WeekDays    Tuesday
# 2    WeekDays  Wednesday
# 3    WeekDays   Thursday
# 4    WeekDays     Friday
# 5    WeekDays   Saturday
# 6    WeekDays     Sunday
# 7   Hyderabad         35
# 8   Hyderabad         36
# 9   Hyderabad         33
# 10  Hyderabad         35
# 11  Hyderabad         38
# 12  Hyderabad         37
# 13  Hyderabad         35
# 14      Delhi         34
# 15      Delhi         32
# 16      Delhi         31
# 17      Delhi         33
# 18      Delhi         35
# 19      Delhi         32
# 20      Delhi         33
# 21      Vizag         38
# 22      Vizag         37
# 23      Vizag         35
# 24      Vizag         36
# 25      Vizag         38
# 26      Vizag         37
# 27      Vizag         35
# 28    Chennai         39
# 29    Chennai         38
# 30    Chennai         37
# 31    Chennai         38
# 32    Chennai         37
# 33    Chennai         35
# 34    Chennai         36

# %%
pd.melt(df1,id_vars=["WeekDays"])
# Out:
#      WeekDays   variable  value
# 0      Monday  Hyderabad     35
# 1     Tuesday  Hyderabad     36
# 2   Wednesday  Hyderabad     33
# 3    Thursday  Hyderabad     35
# 4      Friday  Hyderabad     38
# 5    Saturday  Hyderabad     37
# 6      Sunday  Hyderabad     35
# 7      Monday      Delhi     34
# 8     Tuesday      Delhi     32
# 9   Wednesday      Delhi     31
# 10   Thursday      Delhi     33
# 11     Friday      Delhi     35
# 12   Saturday      Delhi     32
# 13     Sunday      Delhi     33
# 14     Monday      Vizag     38
# 15    Tuesday      Vizag     37
# 16  Wednesday      Vizag     35
# 17   Thursday      Vizag     36
# 18     Friday      Vizag     38
# 19   Saturday      Vizag     37
# 20     Sunday      Vizag     35
# 21     Monday    Chennai     39
# 22    Tuesday    Chennai     38
# 23  Wednesday    Chennai     37
# 24   Thursday    Chennai     38
# 25     Friday    Chennai     37
# 26   Saturday    Chennai     35
# 27     Sunday    Chennai     36

# %%
df2 = pd.melt(df1, id_vars=['WeekDays'])

# %%
df2[df2["variable"] == 'Vizag']
# Out:
#      WeekDays variable  value
# 14     Monday    Vizag     38
# 15    Tuesday    Vizag     37
# 16  Wednesday    Vizag     35
# 17   Thursday    Vizag     36
# 18     Friday    Vizag     38
# 19   Saturday    Vizag     37
# 20     Sunday    Vizag     35

# %%
df1
# Out:
#     WeekDays  Hyderabad  Delhi  Vizag  Chennai
# 0     Monday         35     34     38       39
# 1    Tuesday         36     32     37       38
# 2  Wednesday         33     31     35       37
# 3   Thursday         35     33     36       38
# 4     Friday         38     35     38       37
# 5   Saturday         37     32     37       35
# 6     Sunday         35     33     35       36

# %%
df3 = pd.melt(df1, id_vars=["WeekDays"], var_name="City", value_name="Temperature")

# %%
df3
# Out:
#      WeekDays       City  Temperature
# 0      Monday  Hyderabad           35
# 1     Tuesday  Hyderabad           36
# 2   Wednesday  Hyderabad           33
# 3    Thursday  Hyderabad           35
# 4      Friday  Hyderabad           38
# 5    Saturday  Hyderabad           37
# 6      Sunday  Hyderabad           35
# 7      Monday      Delhi           34
# 8     Tuesday      Delhi           32
# 9   Wednesday      Delhi           31
# 10   Thursday      Delhi           33
# 11     Friday      Delhi           35
# 12   Saturday      Delhi           32
# 13     Sunday      Delhi           33
# 14     Monday      Vizag           38
# 15    Tuesday      Vizag           37
# 16  Wednesday      Vizag           35
# 17   Thursday      Vizag           36
# 18     Friday      Vizag           38
# 19   Saturday      Vizag           37
# 20     Sunday      Vizag           35
# 21     Monday    Chennai           39
# 22    Tuesday    Chennai           38
# 23  Wednesday    Chennai           37
# ...

# %%
df1
# Out:
#     WeekDays  Hyderabad  Delhi  Vizag  Chennai
# 0     Monday         35     34     38       39
# 1    Tuesday         36     32     37       38
# 2  Wednesday         33     31     35       37
# 3   Thursday         35     33     36       38
# 4     Friday         38     35     38       37
# 5   Saturday         37     32     37       35
# 6     Sunday         35     33     35       36

# %%
dfprof = pd.read_csv(r"C:\Users\ajjup\OneDrive\Desktop\DATASETS\DATASETS\Cond Dataset\resume.csv" )

# %%
dfprof
# Out:
#          Full Name          City  State                     Technology
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby

# %%
dfprof["Full Name"]
# Out:
# 0        Arjun Yadav
# 1        Akash Reddy
# 2     Shanti Narayan
# 3        Meena Arjun
# 4        Naren Yadav
# 5        Shiva Kumar
# 6    Srikanth Sharma
# 7         Aman Pandi
# 8      Narayan Reddy
# Name: Full Name, dtype: object

# %%
dfprof['Full Name'].str.split(" ")
# Out:
# 0        [Arjun, Yadav]
# 1        [Akash, Reddy]
# 2     [Shanti, Narayan]
# 3        [Meena, Arjun]
# 4        [Naren, Yadav]
# 5        [Shiva, Kumar]
# 6    [Srikanth, Sharma]
# 7         [Aman, Pandi]
# 8      [Narayan, Reddy]
# Name: Full Name, dtype: object

# %%
dfprof["Full Name"].str.split(' ')
# Out:
# 0        [Arjun, Yadav]
# 1        [Akash, Reddy]
# 2     [Shanti, Narayan]
# 3        [Meena, Arjun]
# 4        [Naren, Yadav]
# 5        [Shiva, Kumar]
# 6    [Srikanth, Sharma]
# 7         [Aman, Pandi]
# 8      [Narayan, Reddy]
# Name: Full Name, dtype: object

# %%
dfname = dfprof["Full Name"].str.split(" ", expand=True )

# %%
dfname
# Out:
#           0        1
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %%
dfname.columns = ["First Name", 'Last Name']

# %%
dfname
# Out:
#   First Name Last Name
# 0      Arjun     Yadav
# 1      Akash     Reddy
# 2     Shanti   Narayan
# 3      Meena     Arjun
# 4      Naren     Yadav
# 5      Shiva     Kumar
# 6   Srikanth    Sharma
# 7       Aman     Pandi
# 8    Narayan     Reddy

# %%
pd.concat([dfprof, dfname], axis= 1)
# Out:
#          Full Name          City  State                     Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName    LName First Name Last Name
# 0     Arjun    Yadav      Arjun     Yadav
# 1     Akash    Reddy      Akash     Reddy
# 2    Shanti  Narayan     Shanti   Narayan
# 3     Meena    Arjun      Meena     Arjun
# 4     Naren    Yadav      Naren     Yadav
# ...

# %%
dfprof['Full Name'].str.split(' ', expand=True)
# Out:
#           0        1
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %% [markdown]
# ### Method 2 to Extract Feature

# %%
dfprof
# Out:
#          Full Name          City  State                     Technology
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby

# %%
dfprof['Full Name']
# Out:
# 0        Arjun Yadav
# 1        Akash Reddy
# 2     Shanti Narayan
# 3        Meena Arjun
# 4        Naren Yadav
# 5        Shiva Kumar
# 6    Srikanth Sharma
# 7         Aman Pandi
# 8      Narayan Reddy
# Name: Full Name, dtype: object

# %%
dfprof['Full Name'].map(lambda x : x.split()[0] )
# Out:
# 0       Arjun
# 1       Akash
# 2      Shanti
# 3       Meena
# 4       Naren
# 5       Shiva
# 6    Srikanth
# 7        Aman
# 8     Narayan
# Name: Full Name, dtype: object

# %%
dfprof["FName"] = dfprof["Full Name"].map(lambda x : x.split()[0])

# %%
dfprof
# Out:
#          Full Name          City  State                     Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName
# 0     Arjun
# 1     Akash
# 2    Shanti
# 3     Meena
# 4     Naren
# 5     Shiva
# 6  Srikanth
# 7      Aman
# 8   Narayan

# %%
dfprof["LName"] = dfprof["Full Name"].map(lambda x : x.split()[1])

# %%
dfprof
# Out:
#          Full Name          City  State                     Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName    LName
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %% [markdown]
# ###  Extract Feature - Method 3

# %%
dfemp = pd.read_csv(r"C:\Users\ajjup\OneDrive\Desktop\DATASETS\DATASETS\Cond Dataset\resume.csv" )

# %%
dfemp
# Out:
#          Full Name          City  State                     Technology
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby

# %%
dfemp[["FName", 'LName']] =  dfemp['Full Name'].str.split( " ", expand = True)

# %%
dfemp
# Out:
#          Full Name          City  State                     Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName    LName
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %%
dfemp
# Out:
#          Full Name          City  State                     Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName    LName
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %%
dfemp["Full Name"]
# Out:
# 0        Arjun Yadav
# 1        Akash Reddy
# 2     Shanti Narayan
# 3        Meena Arjun
# 4        Naren Yadav
# 5        Shiva Kumar
# 6    Srikanth Sharma
# 7         Aman Pandi
# 8      Narayan Reddy
# Name: Full Name, dtype: object

# %%
dfemp["Full Name"].map(lambda x :  x.upper())
# Out:
# 0        ARJUN YADAV
# 1        AKASH REDDY
# 2     SHANTI NARAYAN
# 3        MEENA ARJUN
# 4        NAREN YADAV
# 5        SHIVA KUMAR
# 6    SRIKANTH SHARMA
# 7         AMAN PANDI
# 8      NARAYAN REDDY
# Name: Full Name, dtype: object

# %%
dfemp["Full Name"].str.upper()
# Out:
# 0        ARJUN YADAV
# 1        AKASH REDDY
# 2     SHANTI NARAYAN
# 3        MEENA ARJUN
# 4        NAREN YADAV
# 5        SHIVA KUMAR
# 6    SRIKANTH SHARMA
# 7         AMAN PANDI
# 8      NARAYAN REDDY
# Name: Full Name, dtype: object

# %%
dfemp
# Out:
#          Full Name          City  State                     Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName    LName
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %%
dfemp["Full Name"]
# Out:
# 0        Arjun Yadav
# 1        Akash Reddy
# 2     Shanti Narayan
# 3        Meena Arjun
# 4        Naren Yadav
# 5        Shiva Kumar
# 6    Srikanth Sharma
# 7         Aman Pandi
# 8      Narayan Reddy
# Name: Full Name, dtype: object

# %%
ft = dfemp["Full Name"].str.startswith("S")

# %%
ft
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# Name: Full Name, dtype: bool

# %%
dfemp[ft]
# Out:
#          Full Name          City State                 Technology     FName  \
# 2   Shanti Narayan  Secunderabad    TS       JavaPythonOraclePerl    Shanti
# 5      Shiva Kumar     Hyderabad    TS  PythonJavaScriptPerlMongo     Shiva
# 6  Srikanth Sharma  Secunderabad    TS        JavaRubyPerlAngular  Srikanth
#
#      LName
# 2  Narayan
# 5    Kumar
# 6   Sharma

# %%
dfemp
# Out:
#          Full Name          City  State                     Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName    LName
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %%
dfemp["State"] == "TS"
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# Name: State, dtype: bool

# %%
dfemp[dfemp['State'] == "TS"]
# Out:
#          Full Name          City State                 Technology     FName  \
# 0      Arjun Yadav     Hyderabad    TS   JavaPythonJavaScriptPerl     Arjun
# 2   Shanti Narayan  Secunderabad    TS       JavaPythonOraclePerl    Shanti
# 5      Shiva Kumar     Hyderabad    TS  PythonJavaScriptPerlMongo     Shiva
# 6  Srikanth Sharma  Secunderabad    TS        JavaRubyPerlAngular  Srikanth
#
#      LName
# 0    Yadav
# 2  Narayan
# 5    Kumar
# 6   Sharma

# %%
dfemp
# Out:
#          Full Name          City  State                     Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName    LName
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %%
dfemp['Full Name'].str.replace('Yadav',"Yaduvanshi")
# Out:
# 0    Arjun Yaduvanshi
# 1         Akash Reddy
# 2      Shanti Narayan
# 3         Meena Arjun
# 4    Naren Yaduvanshi
# 5         Shiva Kumar
# 6     Srikanth Sharma
# 7          Aman Pandi
# 8       Narayan Reddy
# Name: Full Name, dtype: object

# %%
str1 = 'Arjun Yadav'

# %%
str1.replace("Yadav", "Yaduvanshi")
# Out:
# 'Arjun Yaduvanshi'

# %%
dfemp['Full Name'].str.replace(" ","")
# Out:
# 0        ArjunYadav
# 1        AkashReddy
# 2     ShantiNarayan
# 3        MeenaArjun
# 4        NarenYadav
# 5        ShivaKumar
# 6    SrikanthSharma
# 7         AmanPandi
# 8      NarayanReddy
# Name: Full Name, dtype: object

# %%
dfemp
# Out:
#          Full Name          City  State                     Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName    LName
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %%
dfcopy = dfemp.copy()

# %%
dfcopy
# Out:
#          Full Name          City  State                     Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName    LName
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %%
dfcopy.columns
# Out:
# Index(['Full Name', 'City', 'State', 'Technology', 'FName', 'LName'], dtype='object')

# %%
dfcopy.columns =  ['Full Name', ' City', 'State ', 'Technology', 'FName', 'LName']

# %%
dfcopy
# Out:
#          Full Name          City State                      Technology  \
# 0      Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 1      Akash Reddy       Chennai     TN         JavaRubyJavaScriptPerl
# 2   Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3      Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4      Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5      Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 6  Srikanth Sharma  Secunderabad     TS            JavaRubyPerlAngular
# 7       Aman Pandi        Bhopal     MP          AngularHtmlPerlOracle
# 8    Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#       FName    LName
# 0     Arjun    Yadav
# 1     Akash    Reddy
# 2    Shanti  Narayan
# 3     Meena    Arjun
# 4     Naren    Yadav
# 5     Shiva    Kumar
# 6  Srikanth   Sharma
# 7      Aman    Pandi
# 8   Narayan    Reddy

# %%
dfcopy["City"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\ajjup\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-3dffec071e3e> in <module>
# ...

# %%
dfcopy.columns
# Out:
# Index(['Full Name', ' City', 'State ', 'Technology', 'FName', 'LName'], dtype='object')

# %%
dfcopy.columns.str.strip()
# Out:
# Index(['Full Name', 'City', 'State', 'Technology', 'FName', 'LName'], dtype='object')

# %%
dfemp['Technology']
# Out:
# 0         JavaPythonJavaScriptPerl
# 1           JavaRubyJavaScriptPerl
# 2             JavaPythonOraclePerl
# 3        JuliaPythonJavaScriptPerl
# 4    JavaPythonJavaScriptSqlserver
# 5        PythonJavaScriptPerlMongo
# 6              JavaRubyPerlAngular
# 7            AngularHtmlPerlOracle
# 8           PythonOracleDjangoRuby
# Name: Technology, dtype: object

# %%
dfemp['Technology'].str.contains("Python")
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# 8     True
# Name: Technology, dtype: bool

# %%
dfemp[dfemp['Technology'].str.contains("Python")]
# Out:
#         Full Name          City  State                     Technology  \
# 0     Arjun Yadav     Hyderabad     TS       JavaPythonJavaScriptPerl
# 2  Shanti Narayan  Secunderabad     TS           JavaPythonOraclePerl
# 3     Meena Arjun        Bhopal     MP      JuliaPythonJavaScriptPerl
# 4     Naren Yadav         Delhi  Delhi  JavaPythonJavaScriptSqlserver
# 5     Shiva Kumar     Hyderabad     TS      PythonJavaScriptPerlMongo
# 8   Narayan Reddy       Chennai     TN         PythonOracleDjangoRuby
#
#      FName    LName
# 0    Arjun    Yadav
# 2   Shanti  Narayan
# 3    Meena    Arjun
# 4    Naren    Yadav
# 5    Shiva    Kumar
# 8  Narayan    Reddy

# %%
dfemp["Technology"].str.contains(("JavaScript"))
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# Name: Technology, dtype: bool

# %%
dfemp[dfemp["Technology"].str.contains(("JavaScript"))]
# Out:
#      Full Name       City  State                     Technology  FName  LName
# 0  Arjun Yadav  Hyderabad     TS       JavaPythonJavaScriptPerl  Arjun  Yadav
# 1  Akash Reddy    Chennai     TN         JavaRubyJavaScriptPerl  Akash  Reddy
# 3  Meena Arjun     Bhopal     MP      JuliaPythonJavaScriptPerl  Meena  Arjun
# 4  Naren Yadav      Delhi  Delhi  JavaPythonJavaScriptSqlserver  Naren  Yadav
# 5  Shiva Kumar  Hyderabad     TS      PythonJavaScriptPerlMongo  Shiva  Kumar

# %%
dfcity = dfemp[["City"]]

# %%
dfcity
# Out:
#            City
# 0     Hyderabad
# 1       Chennai
# 2  Secunderabad
# 3        Bhopal
# 4         Delhi
# 5     Hyderabad
# 6  Secunderabad
# 7        Bhopal
# 8       Chennai

# %%
dfencode = pd.get_dummies(dfcity["City"])

# %%
dfencode
# Out:
#    Bhopal  Chennai  Delhi  Hyderabad  Secunderabad
# 0       0        0      0          1             0
# 1       0        1      0          0             0
# 2       0        0      0          0             1
# 3       1        0      0          0             0
# 4       0        0      1          0             0
# 5       0        0      0          1             0
# 6       0        0      0          0             1
# 7       1        0      0          0             0
# 8       0        1      0          0             0

# %%
df1 = pd.read_csv(r"C:\Users\ajjup\OneDrive\Desktop\Outlier Detection Dataset\Onehotencoding dataset\township.csv")

# %%
df1
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dfen = pd.get_dummies(df1["town"])

# %%
dfen
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
df1
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dfen
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
df1 = pd.concat([df1, dfen], axis = 1).drop("town", axis=1)

# %%
df1
# Out:
#     area   price  monroe township  robinsville  west windsor
# 0   2600  550000                1            0             0
# 1   3000  565000                1            0             0
# 2   3200  610000                1            0             0
# 3   3600  680000                1            0             0
# 4   4000  725000                1            0             0
# 5   2600  585000                0            0             1
# 6   2800  615000                0            0             1
# 7   3300  650000                0            0             1
# 8   3600  710000                0            0             1
# 9   2600  575000                0            1             0
# 10  2900  600000                0            1             0
# 11  3100  620000                0            1             0
# 12  3600  695000                0            1             0

# %%
df1.columns
# Out:
# Index(['area', 'price', 'monroe township', 'robinsville', 'west windsor'], dtype='object')

# %%
df1 = df1[[ 'monroe township', 'robinsville', 'west windsor', 'area', 'price']]

# %%
df1
# Out:
#     monroe township  robinsville  west windsor  area   price
# 0                 1            0             0  2600  550000
# 1                 1            0             0  3000  565000
# 2                 1            0             0  3200  610000
# 3                 1            0             0  3600  680000
# 4                 1            0             0  4000  725000
# 5                 0            0             1  2600  585000
# 6                 0            0             1  2800  615000
# 7                 0            0             1  3300  650000
# 8                 0            0             1  3600  710000
# 9                 0            1             0  2600  575000
# 10                0            1             0  2900  600000
# 11                0            1             0  3100  620000
# 12                0            1             0  3600  695000
